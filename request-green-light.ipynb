# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from time import sleep
import datetime
import pandas as pd
import json

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, NoAlertPresentException, UnexpectedAlertPresentException, ElementClickInterceptedException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

options = Options()
options.headless = True
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.set_window_position(0, 0)
driver.set_window_size(1400, 768)

# %%
sa = gspread.service_account(filename="./credentials/jp-macdonnel-b7aa48547774.json")
sh = sa.open("green-lights")
sheet = sh.worksheet("2022-11-28")

class GreenLight:

  def __init__(self, sheet):
    self.sheet = sheet
    self.df = pd.DataFrame(sheet.get_all_records())
    self.filled_df = self.df[['Customer Name', 'First Name', 'Last Name', 'Job Title', 'Work Phone', 'Email', 'Address Line 1', 'City', 'State', 'Zip Code']]
    self.username = None
    self.password = None
    self.logged_in = False
    self.attempts = 0
    self.input_names = {
      "customer_name": "s_1_1_86_0",
      "first_name": "s_1_1_78_0",
      "last_name": "s_1_1_77_0",
      "job_title": "s_1_1_80_0",
      "email": "s_1_1_99_0",
      "work_phone": "s_1_1_82_0",
      "address_line_1": "s_1_1_94_0",
      "city": "s_1_1_95_0",
      "state": "s_1_1_96_0",
      "zip_code": "s_1_1_97_0",
      "acct_team_owner": "s_1_1_90_0",
      "franchise_name": "s_1_1_61_0",
      "primary_opportunity": "s_1_1_71_0",
      "expected_quantity": "s_1_1_72_0"
    }

  def attempt(self, callback):
    if self.attempts >= 50:
      self.attempts = 0
      raise Exception("attempt limit exceeded")
    print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
    sleep(1)
    self.attempts += 1
    return callback()

  def get_credentials(self):
    file = open("./credentials/unishipper-credentials.json")
    data = json.load(file)
    self.username = data['username']
    self.password = data['password']

  def login(self):
    if not self.username or not self.password:
      self.get_credentials()
    driver.get("http://uone.unishippers.com")
    sleep(3)
    try:
      input_username = driver.find_element(By.ID, 's_swepi_1')
      input_password = driver.find_element(By.ID, 's_swepi_2')
      input_username.send_keys(self.username)
      input_password.send_keys(self.password)
      button_login = driver.find_element(By.ID, "s_swepi_22")
      button_login.click()
      self.attempts = 0
    except NoSuchElementException:
      if "The server you are trying to access is either busy or experiencing difficulties." in driver.find_element(By.TAG_NAME, "body").text:
        sleep(5)
        self.attempt(self.login)
      else:
        self.attempt(self.login)

  def open_leads_tab(self):
    print("opening leads tab")
    try:
      applet = driver.find_element(By.CLASS_NAME, "AppletTitle")
      if applet:
        print("applet")
        tabs = driver.find_elements(By.CLASS_NAME, "ui-corner-top")
        for tab in tabs:
          if tab.text == "Leads":
            tab.click()
            self.attempts = 0
            break
    except NoSuchElementException:
      self.attempt(self.open_leads_tab)

  def start_new_lead(self):
    try:
      button = driver.find_element(By.ID, "s_1_1_110_0_Ctrl")
      print("starting new lead")
      self.attempts = 0
      button.click()
    except NoSuchElementException:
      if self.attempts >= 50:
        self.attempts = 0
        raise Exception("attempt limit exceeded")
      print(f"attempting for the {self.attempts + 1} time")
      sleep(1)
      self.attempts += 1
      self.start_new_lead()

  def fill(self, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code):
    print("filling form")

    inputs = driver.find_elements(By.TAG_NAME, "input")

    for input in inputs:
      try:
        if input.get_attribute('name') == self.input_names['customer_name']:
          input.send_keys(customer_name)
        elif input.get_attribute('name') == self.input_names['first_name']:
          input.send_keys(first_name)
        elif input.get_attribute('name') == self.input_names['last_name']:
          input.send_keys(last_name)
        elif input.get_attribute('name') == self.input_names['job_title']:
          input.send_keys(job_title)
        elif input.get_attribute('name') == self.input_names['email'] and email:
          input.send_keys(email)
        elif input.get_attribute('name') == self.input_names['work_phone']:
          input.send_keys(work_phone)
        elif input.get_attribute('name') == self.input_names['address_line_1']:
          input.send_keys(address)
        elif input.get_attribute('name') == self.input_names['city']:
          input.send_keys(city)
        elif input.get_attribute('name') == self.input_names['state']:
          input.send_keys(state)
        elif input.get_attribute('name') == self.input_names['zip_code']:
          input.send_keys(zip_code)
        elif input.get_attribute('name') == self.input_names['acct_team_owner']:
          input.send_keys("JP.MacDonell")
        elif input.get_attribute('name') == self.input_names['franchise_name']:
          input.send_keys('Unishippers 1578')
        elif input.get_attribute('name') == self.input_names['primary_opportunity']:
          input.send_keys('US Express')
        elif input.get_attribute('name') == self.input_names['expected_quantity']:
          input.send_keys(100)
      except TypeError as e:
        print(e)
      except StaleElementReferenceException as e:
        print("stale element exception error")

  def accept_alert(self):
    try:
      alert = driver.switch_to.alert
      self.attempts = 0
      status = alert.text
      alert.accept()
      print("accepting alert")
      return status
    except NoAlertPresentException:
      return self.attempt(self.accept_alert)

  def check_loading(self):
    html = driver.find_element(By.TAG_NAME, "html")
    if html.get_attribute("class") == "siebui-busy":
      sleep(2.5)
      print("still saving")
      self.check_loading()
    else:
      return

  def save_form(self):
    print("saving form")
    action = ActionChains(driver)
    action.key_down(Keys.CONTROL).send_keys('S').key_up(Keys.CONTROL).perform()
    self.check_loading()

  def check_protection_status(self):
    sleep(.5)
    input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_34_0']")
    val = input.get_attribute("value")
    print(val)
    if val:
      self.attempts = 0
      print("checking protection status")
      return val
    else:
      return self.attempt(self.check_protection_status)

  def update_sales_stage(self):
    print("updating sales stage")
    input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_91_0']")
    input.clear()
    input.send_keys("Prospect")

  def request_green_light(self):
    print("requesting green light")
    driver.find_element(By.ID, 's_1_1_48_0_Ctrl').click()

  def determine_status(self):
    self.save_form()
    sleep(.5)
    protection_status = self.check_protection_status()
    sleep(.5)
    new_status = ""
    if "protected elsewhere" not in protection_status.lower():
      self.update_sales_stage()
      sleep(.5)
      self.save_form()
      sleep(.5)
      self.request_green_light()
      sleep(.5)
      new_status = self.accept_alert()
      self.attempts = 0
    else:
      new_status = protection_status
    print(new_status)
    return new_status

  def update_sheet(self, i, status):
    today = datetime.date.today()
    self.sheet.update(f"K{i+2}", status)
    self.sheet.update(f"L{i+2}", today.strftime("%B %d, %Y"))

  def close_popup(self, text="close"):
    for el in driver.find_elements(By.CLASS_NAME, "ui-button-text"):
      if el.text == text:
        el.click()

  def full_form(self, i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated):
    try:
      if (status):
        print(f"{i}", "\nstatus already exists:", status, updated)
      else:
        sleep(1)
        print(f"{i}", "\nno status, filling in fields")
        self.fill(customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code)
        status = self.determine_status()
        sleep(.5)
        self.update_sheet(i, status)
        sleep(.5)
        self.start_new_lead()
    except UnexpectedAlertPresentException as e:
      print(e)
      alert = driver.switch_to.alert
      self.update_sheet(i, f"UnexpectedAlertPresentException: {alert.text}. \n\nRow may have been skipped.")
      print("unexpected alert; skipping row")
      self.update_sheet(i, "Unexpected alert error; row skipped")
      self.accept_alert()
      self.attempts = 0
    except ElementClickInterceptedException as e:
      print(e)
      self.close_popup()
      sleep(.5)
      status = self.determine_status()
      self.update_sheet(i, status)
      sleep(.5)
      self.start_new_lead()
      try:
        self.request_green_light()
      except:
        self.update_sheet(i, "Element Click Intercepted Exception. Row likely skipped.")

  def iterate(self):
    for i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated in unishippers.df.itertuples():
      print(datetime.datetime.now().strftime("%H:%M:%S"))
      self.full_form(i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated)
      print("\n\n")
      
unishippers = GreenLight(sheet)

# %%
unishippers.login()

# %%
unishippers.open_leads_tab()
# Out:
# opening leads tab
# applet

# %%
unishippers.start_new_lead()
# Out:
# starting new lead

# %%
unishippers.iterate()
# Out:
# 15:36:31
# 0
# status already exists: Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#  November 28, 2022
#
#
#
# 15:36:31
# 1
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 2
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 3
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 4
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 5
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 6
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 7
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 8
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 9
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 10
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 11
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 12
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 13
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 14
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 15
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 16
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 17
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 18
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 19
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 20
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 21
# status already exists: Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#  November 28, 2022
#
#
#
# 15:36:31
# 22
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 23
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 24
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 25
# status already exists: Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#  November 28, 2022
#
#
#
# 15:36:31
# 26
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 27
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 28
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 29
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 30
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 31
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 32
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 33
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 34
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 35
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 36
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 37
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 38
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 39
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 40
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 41
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 42
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 43
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 44
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 45
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 46
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 47
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 48
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 49
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 50
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 51
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 52
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 53
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 54
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 55
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 56
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 57
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 58
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 59
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 60
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 61
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 62
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 63
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 64
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 65
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 66
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 67
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 68
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 69
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 70
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 71
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 72
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 73
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 74
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 75
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 76
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 77
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 78
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 79
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 80
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 81
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 82
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 83
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 84
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 85
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 86
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 87
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 88
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 89
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 90
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 91
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 92
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 93
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 94
# status already exists: Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#  November 28, 2022
#
#
#
# 15:36:31
# 95
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 96
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 97
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 98
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 99
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 100
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 101
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 102
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 103
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 104
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 105
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 106
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 107
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 108
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 109
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 110
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 111
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 112
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 113
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 114
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 115
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 116
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 117
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 118
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 119
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 120
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 121
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 122
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 123
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 124
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 125
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 126
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 127
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 128
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 129
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 130
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 131
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 132
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 133
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 134
# status already exists: Value too long for field 'City' (maximum size 20).(SBL-DAT-00235)
#  November 28, 2022
#
#
#
# 15:36:31
# 135
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 136
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 137
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 138
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 139
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 140
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 141
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 142
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 143
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 144
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 145
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 146
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 147
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 148
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 149
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 150
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 151
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 152
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 153
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 154
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 155
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 156
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 157
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 158
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 159
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 160
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 161
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 162
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 163
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 164
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 165
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 166
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 167
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 168
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 169
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 170
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 171
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 172
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 173
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 174
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 175
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 176
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 177
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 178
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 179
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 180
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 181
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 182
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 183
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 184
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 185
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 186
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 187
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 188
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 189
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 190
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 191
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 192
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 193
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 194
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 195
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 196
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 197
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 198
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 199
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 200
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 201
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 202
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 203
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 204
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 205
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 206
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 207
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 208
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 209
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 210
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 211
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 212
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 213
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 214
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 215
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 216
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 217
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 218
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 219
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 220
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 221
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 222
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 223
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 224
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 225
# status already exists: Protected Elsewhere November 28, 2022
#
#
#
# 15:36:31
# 226
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 227
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 228
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 229
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 230
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 231
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 232
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 233
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 234
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 235
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 236
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 237
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 238
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 239
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 240
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 241
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 242
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 243
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 244
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 245
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 246
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 247
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 248
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 249
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 250
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) November 28, 2022
#
#
#
# 15:36:31
# 251
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:36:57
# 252
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:37:23
# 253
# no status, filling in fields
# filling form
# saving form
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:37:41
# 254
# no status, filling in fields
# filling form
# saving form
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:38:04
# 255
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# still saving
# still saving
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:38:43
# 256
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# still saving
# still saving
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:39:19
# 257
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:39:44
# 258
# no status, filling in fields
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# still saving
# Unprotected
# checking protection status
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 15:40:15
# 259
# no status, filling in fields
# filling form
# ---------------------------------------------------------------------------
# TimeoutException                          Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> unishippers.iterate()
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb Cell 7 in GreenLight.iterate(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=249'>250</a> for i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated in unishippers.df.itertuples():
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=250'>251</a>   print(datetime.datetime.now().strftime("%H:%M:%S"))
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=251'>252</a>   self.full_form(i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=252'>253</a>   print("\n\n")
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb Cell 7 in GreenLight.full_form(self, i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status, updated)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=219'>220</a> sleep(1)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=220'>221</a> print(f"{i}", "\nno status, filling in fields")
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=221'>222</a> self.fill(customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=222'>223</a> status = self.determine_status()
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=223'>224</a> sleep(.5)
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb Cell 7 in GreenLight.fill(self, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code)
#      <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=96'>97</a> def fill(self, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code):
#      <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=97'>98</a>   print("filling form")
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=99'>100</a>   inputs = driver.find_elements(By.TAG_NAME, "input")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=101'>102</a>   for input in inputs:
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request-green-light.ipynb#W6sZmlsZQ%3D%3D?line=102'>103</a>     try:
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:890, in WebDriver.find_elements(self, by, value)
#     886     value = '[name="%s"]' % value
#     888 # Return empty list if driver returns null
#     889 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 890 return self.execute(Command.FIND_ELEMENTS, {
#     891     'using': by,
#     892     'value': value})['value'] or []
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# TimeoutException: Message: timeout: Timed out receiving message from renderer: 300.000
#   (Session info: chrome=107.0.5304.110)
# Stacktrace:
# 0   chromedriver                        0x0000000104986a88 chromedriver + 4123272
# 1   chromedriver                        0x0000000104912778 chromedriver + 3647352
# 2   chromedriver                        0x00000001045d4ac4 chromedriver + 248516
# 3   chromedriver                        0x00000001045c0a4c chromedriver + 166476
# 4   chromedriver                        0x00000001045c0814 chromedriver + 165908
# 5   chromedriver                        0x00000001045bf84c chromedriver + 161868
# 6   chromedriver                        0x00000001045bfcf0 chromedriver + 163056
# 7   chromedriver                        0x00000001045cbd4c chromedriver + 212300
# 8   chromedriver                        0x00000001045dc144 chromedriver + 278852
# 9   chromedriver                        0x00000001045c00a0 chromedriver + 164000
# 10  chromedriver                        0x00000001045dbf00 chromedriver + 278272
# 11  chromedriver                        0x000000010463cf58 chromedriver + 675672
# 12  chromedriver                        0x00000001045feb10 chromedriver + 420624
# 13  chromedriver                        0x00000001045ffc30 chromedriver + 425008
# 14  chromedriver                        0x0000000104958ae4 chromedriver + 3934948
# 15  chromedriver                        0x000000010495bf24 chromedriver + 3948324
# 16  chromedriver                        0x000000010495c508 chromedriver + 3949832
# 17  chromedriver                        0x0000000104962b30 chromedriver + 3975984
# 18  chromedriver                        0x000000010495cb24 chromedriver + 3951396
# 19  chromedriver                        0x000000010493771c chromedriver + 3798812
# 20  chromedriver                        0x00000001049792f0 chromedriver + 4068080
# 21  chromedriver                        0x0000000104979444 chromedriver + 4068420
# 22  chromedriver                        0x000000010498d450 chromedriver + 4150352
# 23  libsystem_pthread.dylib             0x00000001c105d240 _pthread_start + 148
# 24  libsystem_pthread.dylib             0x00000001c1058024 thread_start + 8

# %%
driver.quit()
