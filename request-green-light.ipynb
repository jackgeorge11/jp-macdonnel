# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
sa = gspread.service_account(filename="./credentials/jp-macdonnel-b7aa48547774.json")
sh = sa.open("green-lights")
sheet = sh.worksheet("2022-10-19")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, NoAlertPresentException, UnexpectedAlertPresentException, ElementClickInterceptedException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.set_window_position(0, 0)
driver.set_window_size(1400, 768)

# %%
from time import sleep
import datetime
import pandas as pd
import json

class GreenLight:

  def __init__(self, sheet):
    self.sheet = sheet
    self.df = pd.DataFrame(sheet.get_all_records())
    self.filled_df = self.df[['Customer Name', 'First Name', 'Last Name', 'Job Title', 'Work Phone', 'Address Line 1', 'City', 'State', 'Zip Code']]
    self.username = None
    self.password = None
    self.logged_in = False
    self.attempts = 0
    self.input_names = {
      "customer_name": "s_1_1_86_0",
      "first_name": "s_1_1_78_0",
      "last_name": "s_1_1_77_0",
      "job_title": "s_1_1_80_0",
      "work_phone": "s_1_1_82_0",
      "address_line_1": "s_1_1_94_0",
      "city": "s_1_1_95_0",
      "state": "s_1_1_96_0",
      "zip_code": "s_1_1_97_0",
      "acct_team_owner": "s_1_1_90_0",
      "franchise_name": "s_1_1_61_0",
      "primary_opportunity": "s_1_1_71_0",
      "expected_quantity": "s_1_1_72_0"
    }

  def attempt(self, callback):
    if self.attempts >= 15:
      self.attempts = 0
      raise Exception("attempt limit exceeded")
    print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
    sleep(1)
    self.attempts += 1
    return callback()

  def get_credentials(self):
    file = open("./credentials/unishipper-credentials.json")
    data = json.load(file)
    self.username = data['username']
    self.password = data['password']

  def login(self):
    if not self.username or not self.password:
      self.get_credentials()
    driver.get("http://uone.unishippers.com")
    sleep(3)
    try:
      input_username = driver.find_element(By.ID, 's_swepi_1')
      input_password = driver.find_element(By.ID, 's_swepi_2')
      input_username.send_keys(self.username)
      input_password.send_keys(self.password)
      button_login = driver.find_element(By.ID, "s_swepi_22")
      button_login.click()
      self.attempts = 0
    except NoSuchElementException:
      if "The server you are trying to access is either busy or experiencing difficulties." in driver.find_element(By.TAG_NAME, "body").text:
        sleep(5)
        self.attempt(self.login)
      else:
        self.attempt(self.login)

  def open_leads_tab(self):
    print("opening leads tab")
    try:
      applet = driver.find_element(By.CLASS_NAME, "AppletTitle")
      if applet:
        print("applet")
        tabs = driver.find_elements(By.CLASS_NAME, "ui-corner-top")
        for tab in tabs:
          if tab.text == "Leads":
            tab.click()
            self.attempts = 0
            break
    except NoSuchElementException:
      self.attempt(self.open_leads_tab)

  def start_new_lead(self):
    try:
      button = driver.find_element(By.ID, "s_1_1_110_0_Ctrl")
      button.click()
      self.attempts = 0
    except NoSuchElementException:
      if self.attempts >= 15:
        self.attempts = 0
        raise Exception("attempt limit exceeded")
      print(f"attempting for the {self.attempts + 1} time")
      sleep(1)
      self.attempts += 1
      self.start_new_lead()

  def fill(self, customer_name, first_name, last_name, job_title, work_phone, address, city, state, zip_code):
    inputs = driver.find_elements(By.TAG_NAME, "input")

    for input in inputs:
      try:
        if input.get_attribute('name') == self.input_names['customer_name']:
          input.send_keys(customer_name)
        elif input.get_attribute('name') == self.input_names['first_name']:
          input.send_keys(first_name)
        elif input.get_attribute('name') == self.input_names['last_name']:
          input.send_keys(last_name)
        elif input.get_attribute('name') == self.input_names['job_title']:
          input.send_keys(job_title)
        elif input.get_attribute('name') == self.input_names['work_phone']:
          input.send_keys(work_phone)
        elif input.get_attribute('name') == self.input_names['address_line_1']:
          input.send_keys(address)
        elif input.get_attribute('name') == self.input_names['city']:
          input.send_keys(city)
        elif input.get_attribute('name') == self.input_names['state']:
          input.send_keys(state)
        elif input.get_attribute('name') == self.input_names['zip_code']:
          input.send_keys(zip_code)
        elif input.get_attribute('name') == self.input_names['acct_team_owner']:
          input.send_keys("JP.MacDonell")
        elif input.get_attribute('name') == self.input_names['franchise_name']:
          input.send_keys('Unishippers 1578')
        elif input.get_attribute('name') == self.input_names['primary_opportunity']:
          input.send_keys('US Express')
        elif input.get_attribute('name') == self.input_names['expected_quantity']:
          input.send_keys(100)
      except TypeError as e:
        print(e)

  def accept_alert(self):
    try:
      alert = driver.switch_to.alert
      self.attempts = 0
      status = alert.text
      alert.accept()
      return status
    except NoAlertPresentException:
      return self.attempt(self.accept_alert)

  def save_form(self):
    action = ActionChains(driver)
    action.key_down(Keys.CONTROL).send_keys('S').key_up(Keys.CONTROL).perform()

  def request_green_light(self):
    driver.find_element(By.ID, 's_1_1_48_0_Ctrl').click()

  def update_sheet(self, i, status):
    today = datetime.date.today()
    self.sheet.update(f"J{i+2}", status)
    self.sheet.update(f"K{i+2}", today.strftime("%B %d, %Y"))

  def close_popup(self, text="close"):
    for el in driver.find_elements(By.CLASS_NAME, "ui-button-text"):
      if el.text == text:
        el.click()

  def full_form(self, i, customer_name, first_name, last_name, job_title, work_phone, address, city, state, zip_code, status, updated):
    try:
      sleep(1)
      if (status):
        print(f"\n\n{i}", "\nstatus already exists:", status, updated)
      else:
        print(f"\n\n{i}", "\nno status, filling in fields")
        self.fill(customer_name, first_name, last_name, job_title, work_phone, address, city, state, zip_code)
        print("saving")
        self.save_form()
        sleep(.5)
        print("reuesting green light")
        self.request_green_light()
        sleep(.5)
        print("accepting alert")
        new_status = self.accept_alert()
        self.attempts = 0
        print(new_status)
        self.update_sheet(i, new_status)
        sleep(.5)
        print("starting new lead")
        self.start_new_lead()
    except UnexpectedAlertPresentException as e:
      print(e)
      alert = driver.switch_to.alert
      self.update_sheet(i, f"UnexpectedAlertPresentException: {alert.text}. \n\nRow may have been skipped.")
      print("unexpected alert; skipping row")
      self.update_sheet(i, "Unexpected alert error; row skipped")
      self.accept_alert()
      self.attempts = 0
    except ElementClickInterceptedException as e:
      print(e)
      self.close_popup()
      sleep(.5)
      print("saving")
      self.save_form()
      sleep(.5)
      print("reuesting green light")
      self.request_green_light()
      sleep(.5)
      print("accepting alert")
      new_status = self.accept_alert()
      self.attempts = 0
      print(new_status)
      self.update_sheet(i, new_status)
      sleep(.5)
      print("starting new lead")
      self.start_new_lead()
      try:
        self.request_green_light()
      except:
        self.update_sheet(i, "Element Click Intercepted Exception. Row likely skipped.")

  def iterate(self):
    for i, customer_name, first_name, last_name, job_title, work_phone, address, city, state, zip_code, status, updated in unishippers.df.itertuples():
      self.full_form(i, customer_name, first_name, last_name, job_title, work_phone, address, city, state, zip_code, status, updated)
      
unishippers = GreenLight(sheet)

# %%
unishippers.login()

# %%
unishippers.open_leads_tab()
# Out:
# opening leads tab
# applet

# %%
unishippers.start_new_lead()

# %%
unishippers.iterate()
# Out:
# 0
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 1
# status already exists: Unexpected alert error; row skipped October 22, 2022
#
#
# 2
# status already exists: Unexpected alert error; row skipped October 22, 2022
#
#
# 3
# status already exists: Unexpected alert error; row skipped October 22, 2022
#
#
# 4
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 5
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 6
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 7
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 8
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 9
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 10
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 11
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 12
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 13
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 14
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 15
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 16
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 17
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 18
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 19
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 20
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 21
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 22
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 23
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 24
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 25
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 26
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 27
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 28
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 29
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 22, 2022
#
#
# 30
# status already exists: [1]Error invoking service 'SetNewLeadStatus', method 'Set_LeadStatus' at step 'Set Dates and Status'.(SBL-BPR-00162)
# [2]This operation is not available for read only field 'ABCD Account Status'.(SBL-DAT-00402)
#  October 22, 2022
#
#
# 31
# status already exists: Unexpected alert error; row skipped October 25, 2022
#
#
# 32
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 33
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 34
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 35
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 36
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 37
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 38
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 39
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 40
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 41
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 42
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 43
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 44
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 45
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 46
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 47
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 48
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 49
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 50
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 51
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 52
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 53
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 54
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 55
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 56
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 57
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 58
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 59
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 60
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 61
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 62
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 63
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 64
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 65
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 66
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 67
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 68
# status already exists: Unexpected alert error; row skipped October 25, 2022
#
#
# 69
# status already exists: Unexpected alert error; row skipped October 25, 2022
#
#
# 70
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 71
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 72
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 73
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 74
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 75
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 76
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 77
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 78
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 79
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 80
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 81
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 82
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 83
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 84
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 85
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 86
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 87
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 88
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 89
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 90
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 91
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 92
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 93
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 94
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 95
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 96
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 97
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 98
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 99
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 100
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 101
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 102
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 103
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 104
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 105
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 106
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 107
# status already exists: This operation is not allowed when there are no records displayed.
#
# Please execute a query that returns at least one record or add a new record.(SBL-DAT-00215)
#  October 25, 2022
#
#
# 108
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 109
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 110
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 111
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 112
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 113
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 114
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 115
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 116
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 117
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 118
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 119
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 120
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 121
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 122
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 123
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 124
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 125
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 126
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 127
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 128
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 129
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 130
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 131
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 132
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 133
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 134
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 135
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 136
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 137
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 138
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151) October 25, 2022
#
#
# 139
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 140
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 141
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 142
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 143
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# attempting accept_alert for the 5 time
# attempting accept_alert for the 6 time
# attempting accept_alert for the 7 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 144
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 145
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 146
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 147
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 148
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 149
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 150
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 151
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 152
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 153
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 154
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 155
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 156
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 157
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 158
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 159
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 160
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 161
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 162
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 163
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 164
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#
# starting new lead
#
#
# 165
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 166
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 167
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 168
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 169
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# attempting accept_alert for the 5 time
# attempting accept_alert for the 6 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 170
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 171
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 172
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# attempting accept_alert for the 5 time
# attempting accept_alert for the 6 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 173
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 174
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 175
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 176
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 177
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 178
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# attempting accept_alert for the 5 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 179
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 180
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 181
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 182
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 183
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 184
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 185
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 186
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 187
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 188
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 189
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 190
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 191
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 192
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 193
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 194
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 195
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 196
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 197
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 198
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 199
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 200
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 201
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 202
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 203
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 204
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 205
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 206
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# attempting accept_alert for the 5 time
# attempting accept_alert for the 6 time
# attempting accept_alert for the 7 time
# attempting accept_alert for the 8 time
# attempting accept_alert for the 9 time
# attempting accept_alert for the 10 time
# attempting accept_alert for the 11 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 207
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 208
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 209
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 210
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 211
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 212
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 213
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 214
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 215
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 216
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# attempting accept_alert for the 3 time
# attempting accept_alert for the 4 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 217
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 218
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 219
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 220
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 221
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 222
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Value too long for field 'Address1' (maximum size 30).(SBL-DAT-00235)
#
# starting new lead
#
#
# 223
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 224
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 225
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
# 226
# no status, filling in fields
# saving
# reuesting green light
# accepting alert
# attempting accept_alert for the 1 time
# attempting accept_alert for the 2 time
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
