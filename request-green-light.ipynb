# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from time import sleep
import datetime
import pandas as pd
import json

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, NoAlertPresentException, UnexpectedAlertPresentException, ElementClickInterceptedException, StaleElementReferenceException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

options = Options()
options.headless = True
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.set_window_position(0, 0)
driver.set_window_size(1400, 768)

# %%
sa = gspread.service_account(filename="./credentials/jp-macdonnel-b7aa48547774.json")
sh = sa.open("green-lights")
sheet = sh.worksheet("2023-02-26")
master = sh.worksheet("master")
df_master = pd.DataFrame(master.get_all_records())


class InvalidAddressException(Exception):
    "Raised when an address can't be parsed."
    pass


class InvalidStateError(Exception):
    "Raised when an address can't be parsed."
    pass


us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}


class GreenLight:
    def __init__(self, sheet):
        self.sheet = sheet
        self.df = pd.DataFrame(sheet.get_all_records())
        self.filled_df = self.df[
            [
                "Customer Name",
                "First Name",
                "Last Name",
                "Job Title",
                "Work Phone",
                "Email",
                "Address Line 1",
                "City",
                "State",
                "Zip Code",
            ]
        ]
        self.username = None
        self.password = None
        self.logged_in = False
        self.attempts = 0
        self.input_names = {
            "customer_name": "s_1_1_86_0",
            "first_name": "s_1_1_78_0",
            "last_name": "s_1_1_77_0",
            "job_title": "s_1_1_80_0",
            "email": "s_1_1_99_0",
            "work_phone": "s_1_1_82_0",
            "address_line_1": "s_1_1_94_0",
            "city": "s_1_1_95_0",
            "state": "s_1_1_96_0",
            "zip_code": "s_1_1_97_0",
            "acct_team_owner": "s_1_1_90_0",
            "franchise_name": "s_1_1_61_0",
            "primary_opportunity": "s_1_1_71_0",
            "expected_quantity": "s_1_1_72_0",
        }
        self.seen_companies = set()
        for item in df_master["Customer Name"].values.tolist():
            self.seen_companies.add(item)

    def parse_address(self, address):
        try:
            split = address.split(",")
            strip = [item.strip() for item in split]
            if len(split) < 5:
                raise InvalidAddressException
            elif len(split) == 5:
                return {
                    "address": strip[0],
                    "city": strip[1],
                    "state": strip[2],
                    "zip_code": strip[4][:5],
                }
            else:
                return {
                    "address": strip[0],
                    "city": strip[-4],
                    "state": strip[-3],
                    "zip_code": strip[-1][:5],
                }
        except:
            print("Couldn't parse address. Skipping Row.")
            raise InvalidAddressException

    def parse_state(self, state):
        try:
            return us_state_to_abbrev[state]
        except:
            print("Couldn't convert state to ISO. Skipping Row.")
            raise InvalidStateError

    def attempt(self, callback):
        if self.attempts >= 50:
            self.attempts = 0
            raise Exception("attempt limit exceeded")
        print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
        sleep(1)
        self.attempts += 1
        return callback()

    def get_credentials(self):
        file = open("./credentials/unishipper-credentials.json")
        data = json.load(file)
        self.username = data["username"]
        self.password = data["password"]

    def login(self):
        if not self.username or not self.password:
            self.get_credentials()
        driver.get("http://uone.unishippers.com")
        sleep(3)
        try:
            input_username = driver.find_element(By.ID, "s_swepi_1")
            input_password = driver.find_element(By.ID, "s_swepi_2")
            input_username.send_keys(self.username)
            input_password.send_keys(self.password)
            button_login = driver.find_element(By.ID, "s_swepi_22")
            button_login.click()
            self.attempts = 0
        except NoSuchElementException:
            if (
                "The server you are trying to access is either busy or experiencing difficulties."
                in driver.find_element(By.TAG_NAME, "body").text
            ):
                sleep(5)
                self.attempt(self.login)
            else:
                self.attempt(self.login)

    def open_leads_tab(self):
        print("opening leads tab")
        try:
            applet = driver.find_element(By.CLASS_NAME, "AppletTitle")
            if applet:
                print("applet")
                tabs = driver.find_elements(By.CLASS_NAME, "ui-corner-top")
                for tab in tabs:
                    if tab.text == "Leads":
                        tab.click()
                        self.attempts = 0
                        break
        except NoSuchElementException:
            self.attempt(self.open_leads_tab)

    def start_new_lead(self):
        try:
            button = driver.find_element(By.ID, "s_1_1_110_0_Ctrl")
            print("starting new lead")
            self.attempts = 0
            button.click()
        except NoSuchElementException:
            if self.attempts >= 50:
                self.attempts = 0
                raise Exception("attempt limit exceeded")
            print(f"attempting for the {self.attempts + 1} time")
            sleep(1)
            self.attempts += 1
            self.start_new_lead()

    def compare_customer_to_master(self, customer_name):
        return customer_name in self.seen_companies

    def fill(
        self,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
    ):
        print("filling form")

        inputs = driver.find_elements(By.TAG_NAME, "input")

        for input in inputs:
            try:
                if input.get_attribute("name") == self.input_names["customer_name"]:
                    input.send_keys(customer_name)
                elif input.get_attribute("name") == self.input_names["first_name"]:
                    input.send_keys(first_name)
                elif input.get_attribute("name") == self.input_names["last_name"]:
                    input.send_keys(last_name)
                elif input.get_attribute("name") == self.input_names["job_title"]:
                    input.send_keys(job_title)
                elif input.get_attribute("name") == self.input_names["email"] and email:
                    input.send_keys(email)
                elif input.get_attribute("name") == self.input_names["work_phone"]:
                    input.send_keys(work_phone)
                elif input.get_attribute("name") == self.input_names["address_line_1"]:
                    if len(address) > 30:
                        address = address[:30]
                    input.send_keys(address)
                elif input.get_attribute("name") == self.input_names["city"]:
                    input.send_keys(city)
                elif input.get_attribute("name") == self.input_names["state"]:
                    input.send_keys(state)
                elif input.get_attribute("name") == self.input_names["zip_code"]:
                    input.send_keys(zip_code)
                elif input.get_attribute("name") == self.input_names["acct_team_owner"]:
                    input.send_keys("JP.MacDonell")
                elif input.get_attribute("name") == self.input_names["franchise_name"]:
                    input.send_keys("Unishippers 1578")
                elif (
                    input.get_attribute("name")
                    == self.input_names["primary_opportunity"]
                ):
                    input.send_keys("US Express")
                elif (
                    input.get_attribute("name") == self.input_names["expected_quantity"]
                ):
                    input.send_keys(100)
            except TypeError as e:
                print(e)
            except StaleElementReferenceException as e:
                print("stale element exception error")

    def accept_alert(self):
        try:
            alert = driver.switch_to.alert
            self.attempts = 0
            status = alert.text
            alert.accept()
            print("accepting alert")
            return status
        except NoAlertPresentException:
            return self.attempt(self.accept_alert)

    def check_loading(self):
        html = driver.find_element(By.TAG_NAME, "html")
        if html.get_attribute("class") == "siebui-busy":
            sleep(2.5)
            print("still saving")
            self.check_loading()
        else:
            return

    def save_form(self):
        print("saving form")
        action = ActionChains(driver)
        action.key_down(Keys.CONTROL).send_keys("S").key_up(Keys.CONTROL).perform()
        self.check_loading()

    def check_protection_status(self):
        sleep(0.5)
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_34_0']")
        val = input.get_attribute("value")
        print(val)
        if val:
            self.attempts = 0
            print("checking protection status")
            return val
        else:
            return self.attempt(self.check_protection_status)

    def check_protected_until(self):
        sleep(0.5)
        # fix next line
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_33_0']")
        val = input.get_attribute("value")
        print(val)
        if val:
            self.attempts = 0
            print("checking protected until")
            return val
        else:
            if self.attempts > 4:
                self.attempts = 0
                status = "Unable to get protected until date"
                print(status)
                return status
            return self.attempt(self.check_protected_until)

    def update_sales_stage(self):
        print("updating sales stage")
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_91_0']")
        input.clear()
        input.send_keys("Prospect")

    def request_green_light(self):
        print("requesting green light")
        driver.find_element(By.ID, "s_1_1_48_0_Ctrl").click()

    def determine_status_and_protected_until(self):
        self.save_form()
        sleep(0.5)
        protection_status = self.check_protection_status()
        sleep(0.5)
        protected_until = self.check_protected_until()
        new_status = ""
        if "protected elsewhere" not in protection_status.lower():
            self.update_sales_stage()
            sleep(0.5)
            self.save_form()
            sleep(0.5)
            self.request_green_light()
            sleep(0.5)
            new_status = self.accept_alert()
            self.attempts = 0
        else:
            new_status = protection_status
        print(new_status)
        return [new_status, protected_until]

    def update_sheet(self, i, status, protected_until=""):
        today = datetime.datetime.now()
        self.sheet.update(f"K{i+2}", status)
        self.sheet.update(f"L{i+2}", today.strftime("%B %d, %Y – %H:%M:%S"))
        if protected_until:
            self.sheet.update(f"M{i+2}", protected_until)

    def close_popup(self, text="close"):
        for el in driver.find_elements(By.CLASS_NAME, "ui-button-text"):
            if el.text == text:
                el.click()

    def full_form(
        self,
        i,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
        status,
    ):
        try:
            if status:
                print(f"{i}", "\nstatus already exists:", status)
            elif not (customer_name and address):
                status = "Insufficient info. Skipping row."
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            elif self.compare_customer_to_master(customer_name):
                status = f"Customer already exists in master: {customer_name}"
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            else:
                self.seen_companies.add(customer_name)
                print(f"{i}", "\nno status, filling in fields")
                work_phone = (
                    work_phone
                    if work_phone and work_phone != "#ERROR!"
                    else "(310) 000-0000"
                )
                first_name = first_name if first_name else "FakeFirstName"
                last_name = last_name if last_name else "FakeLastName"
                if not (city or state or zip_code):
                    print(
                        "no city, state, or zip code. Atempting to parse address.",
                    )
                    parsed = self.parse_address(address)
                    address = parsed["address"]
                    city = parsed["city"]
                    state = parsed["state"]
                    zip_code = parsed["zip_code"]
                sleep(1)
                if not (address or city or state or zip_code):
                    status = "Insufficient address info. Skipping row."
                else:
                    if len(state) > 2:
                        state = self.parse_state(state)
                    self.fill(
                        customer_name,
                        first_name,
                        last_name,
                        job_title,
                        work_phone,
                        email,
                        address,
                        city,
                        state,
                        zip_code,
                    )
                    [
                        status,
                        protected_until,
                    ] = self.determine_status_and_protected_until()
                sleep(0.5)
                self.update_sheet(i, status, protected_until)
                sleep(0.5)
                self.start_new_lead()
        except UnexpectedAlertPresentException as e:
            print(e)
            alert = driver.switch_to.alert
            self.update_sheet(
                i,
                f"UnexpectedAlertPresentException: {alert.text}. \n\nRow may have been skipped.",
            )
            print("unexpected alert; skipping row")
            self.update_sheet(i, "Unexpected alert error; row skipped")
            self.accept_alert()
            self.attempts = 0
        except ElementClickInterceptedException as e:
            print(e)
            self.close_popup()
            sleep(0.5)
            status = self.determine_status_and_protected_until()
            self.update_sheet(i, status)
            sleep(0.5)
            self.start_new_lead()
            try:
                self.request_green_light()
            except:
                self.update_sheet(
                    i, "Element Click Intercepted Exception. Row likely skipped."
                )
        except InvalidStateError as e:
            print(e)
            self.update_sheet(
                i,
                "Key Error. Unable to convert state name to ISO code. Row likely skipped.",
            )
        except InvalidAddressException as e:
            print(e)
            self.update_sheet(i, "Invalid Address. Row likely skipped.")

    def iterate(self, start=0, end=None):
        # changed unishippers to self might need to change back
        df = self.df
        if end:
            df = df[start:end]
        for (
            i,
            customer_name,
            first_name,
            last_name,
            job_title,
            work_phone,
            email,
            address,
            city,
            state,``
            zip_code,
            status,
            updated,
            protected_until,
        ) in df.itertuples():
            print(datetime.datetime.now().strftime("%H:%M:%S"))
            self.full_form(
                i,
                customer_name,
                first_name,
                last_name,
                job_title,
                work_phone,
                email,
                address,
                city,
                state,
                zip_code,
                status,
            )
            print("\n\n")


unishippers = GreenLight(sheet)

# %%
unishippers.login()

# %%
unishippers.open_leads_tab()
# Out:
# opening leads tab
# applet

# %%
unishippers.start_new_lead()
# Out:
# attempting for the 1 time
# starting new lead

# %%
unishippers.iterate()
# Out:
# 07:55:26
# 0
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 1
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 2
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 3
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 4
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 5
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 6
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 7
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 8
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 9
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 10
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 11
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 12
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 13
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 14
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 15
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 16
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 17
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 18
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 19
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 20
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 21
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 22
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 23
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 24
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 25
# status already exists: Customer already exists in master: Auto House
#
#
#
# 07:55:26
# 26
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 27
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 28
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 29
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 30
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 31
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 32
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 33
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 34
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 35
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 36
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 37
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 38
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 39
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 40
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 41
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 42
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 43
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 44
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 45
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 46
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 47
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 48
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 07:55:26
# 49
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 50
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 51
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 52
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 53
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 54
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 55
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 56
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 57
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 58
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 59
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 60
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 61
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 62
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 63
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 64
# status already exists: Customer already exists in master: Bressler's
#
#
#
# 07:55:26
# 65
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 66
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 67
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 68
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 69
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 70
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 71
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 72
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 73
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 74
# status already exists: Customer already exists in master: Bill Kidd's
#
#
#
# 07:55:26
# 75
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 76
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 77
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 78
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 79
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 80
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 81
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 82
# status already exists: Customer already exists in master: Baker Chrysler Jeep Dodge
#
#
#
# 07:55:26
# 83
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 84
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 85
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 86
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 87
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 88
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 89
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 90
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 91
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 92
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 93
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 94
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 95
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 96
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 97
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 98
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 99
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 100
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 101
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 102
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 103
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 104
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 105
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 106
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 107
# status already exists: Customer already exists in master: Calstar Motors
#
#
#
# 07:55:26
# 108
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 109
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 110
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 111
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 112
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 113
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 114
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 115
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 116
# status already exists: Customer already exists in master: College Station Ford
#
#
#
# 07:55:26
# 117
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 118
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 119
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 120
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 121
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 122
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 123
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 124
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 125
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 126
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 127
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 128
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 129
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 130
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 131
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 132
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 133
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 134
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 135
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 136
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 137
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 138
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 139
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 140
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 141
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 142
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 143
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 144
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 145
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 146
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 147
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 148
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 149
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 150
# status already exists: Customer already exists in master: Folsom Lake Chrysler Dodge Jeep Ram
#
#
#
# 07:55:26
# 151
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 152
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 153
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 154
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 155
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 156
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 157
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 158
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 159
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 160
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 161
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 162
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 163
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 164
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 165
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 166
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 167
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 168
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 169
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 170
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 171
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 172
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 173
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 174
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 175
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 176
# status already exists: Customer already exists in master: Bespoke Motor Group
#
#
#
# 07:55:26
# 177
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 178
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 179
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 180
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 181
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 182
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 183
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 184
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 185
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 186
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 187
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 188
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 189
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 190
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 191
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 192
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 193
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 194
# status already exists: Customer already exists in master: Clear Lake Nissan
#
#
#
# 07:55:26
# 195
# status already exists: Customer already exists in master: Madera Toyota
#
#
#
# 07:55:26
# 196
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 197
# status already exists: Customer already exists in master: Community Toyota
#
#
#
# 07:55:26
# 198
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 199
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 200
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 201
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 202
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 203
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 204
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 205
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 206
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 207
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 208
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 209
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 210
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 211
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 212
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 213
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 214
# status already exists: Customer already exists in master: Carr Subaru
#
#
#
# 07:55:26
# 215
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 216
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 217
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 218
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 219
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 220
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 221
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 07:55:26
# 222
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 223
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 224
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 225
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 226
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 227
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 228
# status already exists: Customer already exists in master: Chapman Auto Stores
#
#
#
# 07:55:26
# 229
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 230
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 231
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 232
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 233
# status already exists: Customer already exists in master: Allen Family Automotive Group
#
#
#
# 07:55:26
# 234
# status already exists: Customer already exists in master: Ciocca Chevrolet of West Chester
#
#
#
# 07:55:26
# 235
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 236
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 237
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 238
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 239
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 240
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 241
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 242
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 243
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 244
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 245
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 246
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 247
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 248
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 249
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 250
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 251
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 252
# status already exists: Customer already exists in master: Madera Toyota
#
#
#
# 07:55:26
# 253
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 254
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 255
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 256
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 257
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 258
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 259
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 260
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 261
# status already exists: Customer already exists in master: Audi Jackson
#
#
#
# 07:55:26
# 262
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 263
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 264
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 265
# status already exists: Customer already exists in master: Banner Automotive Group
#
#
#
# 07:55:26
# 266
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 267
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 268
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 269
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 270
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 271
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 272
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 273
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 274
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 275
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 276
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 277
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 278
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 279
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 280
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 281
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 282
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 283
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 284
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 285
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 286
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 287
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 288
# status already exists: Customer already exists in master: Butler Toyota
#
#
#
# 07:55:26
# 289
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 07:55:26
# 290
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 291
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 292
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 293
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 294
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 295
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 296
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 297
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 298
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 299
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 300
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 301
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 302
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 303
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 304
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 305
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 306
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 307
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 308
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 309
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 310
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 311
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 312
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 313
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 314
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 315
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 316
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 317
# status already exists: Customer already exists in master: Anderson Subaru
#
#
#
# 07:55:26
# 318
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 319
# status already exists: Customer already exists in master: Audi Central Houston
#
#
#
# 07:55:26
# 320
# status already exists: Customer already exists in master: Brother's Chevrolet
#
#
#
# 07:55:26
# 321
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 322
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 323
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 324
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 325
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 326
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 327
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 328
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 329
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 330
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 331
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 332
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 333
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 334
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 335
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 336
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 337
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 338
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 339
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 340
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 341
# status already exists: Customer already exists in master: Ardmore Nissan
#
#
#
# 07:55:26
# 342
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 343
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 344
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 345
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 346
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 347
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 348
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 349
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 350
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 351
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 352
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 353
# status already exists: Customer already exists in master: Pal Ortho Lab
#
#
#
# 07:55:26
# 354
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 355
# status already exists: Customer already exists in master: Kinetic Dental Lab
#
#
#
# 07:55:26
# 356
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 357
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 358
# status already exists: Customer already exists in master: Next Level Dental Concepts
#
#
#
# 07:55:26
# 359
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 360
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 361
# status already exists: Customer already exists in master: Gnathodontics
#
#
#
# 07:55:26
# 362
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 363
# status already exists: Customer already exists in master: Golden Ceramic Dental Lab
#
#
#
# 07:55:26
# 364
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 365
# status already exists: Customer already exists in master: AMG Creative
#
#
#
# 07:55:26
# 366
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 367
# status already exists: Customer already exists in master: Ziemek Dental Lab
#
#
#
# 07:55:26
# 368
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 369
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 370
# status already exists: Customer already exists in master: Cap City Dental Lab
#
#
#
# 07:55:26
# 371
# status already exists: Customer already exists in master: Laguna Dental Arts
#
#
#
# 07:55:26
# 372
# status already exists: Customer already exists in master: Malcamp Dental Ceramics
#
#
#
# 07:55:26
# 373
# status already exists: Customer already exists in master: Marotta Dental Studio
#
#
#
# 07:55:26
# 374
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 375
# status already exists: Customer already exists in master: Method Air
#
#
#
# 07:55:26
# 376
# status already exists: Customer already exists in master: Collins Orthodontics
#
#
#
# 07:55:26
# 377
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 378
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 379
# status already exists: Customer already exists in master: TS Labs
#
#
#
# 07:55:26
# 380
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 381
# status already exists: Customer already exists in master: Gergen's Orthodontic Lab
#
#
#
# 07:55:26
# 382
# status already exists: Customer already exists in master: Mid-South Dental Lab
#
#
#
# 07:55:26
# 383
# status already exists: Customer already exists in master: Nakanishi Dental Laboratory
#
#
#
# 07:55:26
# 384
# status already exists: Customer already exists in master: Wickert Dental Lab
#
#
#
# 07:55:26
# 385
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 386
# status already exists: Customer already exists in master: Infusion Dental Arts
#
#
#
# 07:55:26
# 387
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 388
# status already exists: You have already submitted the request(SBL-EXL-00151)
#
#
#
# 07:55:26
# 389
# status already exists: Customer already exists in master: Partners Dental Studio
#
#
#
# 07:55:26
# 390
# status already exists: Customer already exists in master: Accutech Orthodontic Lab
#
#
#
# 07:55:26
# 391
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 392
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 393
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 394
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 395
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 396
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 397
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 398
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 399
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 400
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 401
# status already exists: Customer already exists in master: Molina/Watson Dental Technologies
#
#
#
# 07:55:26
# 402
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 403
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 404
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 405
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 406
# status already exists: Customer already exists in master: GNS Dental Studio
#
#
#
# 07:55:26
# 407
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 408
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 409
# status already exists: Customer already exists in master: Treasure Dental Studio
#
#
#
# 07:55:26
# 410
# status already exists: Customer already exists in master: JC's Dental Designs
#
#
#
# 07:55:26
# 411
# status already exists: Customer already exists in master: Hardin Dental Lab
#
#
#
# 07:55:26
# 412
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 413
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 414
# status already exists: Customer already exists in master: Synergy Dental Lab
#
#
#
# 07:55:26
# 415
# status already exists: Customer already exists in master: Ultimate Dental
#
#
#
# 07:55:26
# 416
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 417
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 418
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 419
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 420
# status already exists: Customer already exists in master: Treasure Dental Studio
#
#
#
# 07:55:26
# 421
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 422
# status already exists: Customer already exists in master: Murray Kaizer
#
#
#
# 07:55:26
# 423
# status already exists: Customer already exists in master: Studio 32 Dental Laboratory
#
#
#
# 07:55:26
# 424
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 425
# status already exists: Customer already exists in master: Innovation Dental
#
#
#
# 07:55:26
# 426
# status already exists: Customer already exists in master: Suncoast Ceramic Studio
#
#
#
# 07:55:26
# 427
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 428
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 429
# status already exists: Customer already exists in master: Life Like Dental Lab
#
#
#
# 07:55:26
# 430
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 431
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 432
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 433
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 07:55:26
# 434
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 435
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 436
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 437
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 438
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 439
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 440
# status already exists: Customer already exists in master: Anderson Dental Studio
#
#
#
# 07:55:26
# 441
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 442
# status already exists: Customer already exists in master: Lovett Dental Lab
#
#
#
# 07:55:26
# 443
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 444
# status already exists: Customer already exists in master: Lovett Dental Lab
#
#
#
# 07:55:26
# 445
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 446
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 447
# status already exists: Customer already exists in master: North Creek Dental Lab
#
#
#
# 07:55:26
# 448
# status already exists: Customer already exists in master: Oral Restorative Prosthetics
#
#
#
# 07:55:26
# 449
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 450
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 451
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 452
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 453
# status already exists: Customer already exists in master: Suncoast Ceramic Studio
#
#
#
# 07:55:26
# 454
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 455
# status already exists: Customer already exists in master: Thorn Ford Dental Laboratory
#
#
#
# 07:55:26
# 456
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 457
# status already exists: Customer already exists in master: Allure Dental Studio
#
#
#
# 07:55:26
# 458
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 459
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 460
# status already exists: Customer already exists in master: Ortho Incentives
#
#
#
# 07:55:26
# 461
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 462
# status already exists: Customer already exists in master: Great State Dental Laboratory
#
#
#
# 07:55:26
# 463
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 464
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 465
# status already exists: Customer already exists in master: Precision Dental Restoration
#
#
#
# 07:55:26
# 466
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 467
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 468
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 469
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 470
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 471
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 472
# status already exists: Insufficient info. Skipping row.
#
#
#
# 07:55:26
# 473
# status already exists: Customer already exists in master: Mint Dental Lab
#
#
#
# 07:55:26
# 474
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 475
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 476
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 477
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 478
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 479
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 480
# status already exists: Customer already exists in master: Headcase
#
#
#
# 07:55:26
# 481
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 482
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 483
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 484
# ...
# 952
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 953
# status already exists: Customer already exists in master: Sportique
#
#
#
# 07:55:26
# 954
# status already exists: Customer already exists in master: Stemple Creek Ranch
#
#
#
# 07:55:26
# 955
# status already exists: Customer already exists in master: Stemple Creek Ranch
#
#
#
# 07:55:26
# 956
# status already exists: Customer already exists in master: Strike Industries
#
#
#
# 07:55:26
# 957
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 958
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 959
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 960
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 961
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 962
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 963
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 964
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 965
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 966
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 967
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 968
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 969
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 970
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 971
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 972
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 973
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 974
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 975
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 976
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 977
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 978
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 979
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 980
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 981
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 982
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 983
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 984
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 985
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 986
# status already exists: Customer already exists in master: TIES
#
#
#
# 07:55:26
# 987
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 988
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 989
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 990
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 991
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 992
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 993
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 994
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 995
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 996
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 07:55:26
# 997
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 998
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 999
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 1000
# status already exists: Protected Elsewhere
#
#
#
# 07:55:26
# 1001
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 07:55:26
# 1002
# status already exists: Customer already exists in master: True Nutrition
#
#
#
# 07:55:26
# 1003
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:55:48
# 1004
# Customer already exists in master: Two Way Direct
#
#
#
# 07:55:50
# 1005
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:56:08
# 1006
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:56:27
# 1007
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
#
#
#
#
# 07:56:27
# 1008
# Customer already exists in master: Urban Kitchen Group
#
#
#
# 07:56:28
# 1009
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:56:49
# 1010
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:57:10
# 1011
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:57:29
# 1012
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:57:47
# 1013
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:58:07
# 1014
# Customer already exists in master: Vintage Cellars
#
#
#
# 07:58:07
# 1015
# Customer already exists in master: Vintage Cellars
#
#
#
# 07:58:08
# 1016
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
#
#
#
#
# 07:58:08
# 1017
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:58:34
# 1018
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Unprotected
# checking protection status
#
# attempting check_protected_until for the 1 time
#
# attempting check_protected_until for the 2 time
#
# attempting check_protected_until for the 3 time
#
# attempting check_protected_until for the 4 time
#
# attempting check_protected_until for the 5 time
#
# attempting check_protected_until for the 6 time
#
# attempting check_protected_until for the 7 time
#
# attempting check_protected_until for the 8 time
#
# attempting check_protected_until for the 9 time
#
# attempting check_protected_until for the 10 time
#
# attempting check_protected_until for the 11 time
#
# Unable to get protected until date
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:59:10
# 1019
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:59:28
# 1020
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 07:59:47
# 1021
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# attempting accept_alert for the 1 time
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:00:09
# 1022
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# saving form
# still saving
# Protected Elsewhere
# checking protection status
# 2/26/2023 12:00:00 AM
# checking protected until
# Protected Elsewhere
# starting new lead
#
#
#
# 08:00:23
# 1023
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:00:45
# 1024
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:01:04
# 1025
# Customer already exists in master: WineCountry Media
#
#
#
# 08:01:04
# 1026
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:01:25
# 1027
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:01:44
# 1028
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:02:08
# 1029
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:02:29
# 1030
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:02:55
# 1031
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:03:16
# 1032
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# stale element exception error
# saving form
# still saving
# still saving
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:03:42
# 1033
# no status, filling in fields
# no city, state, or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# Protected
# checking protection status
# 3/6/2023 12:00:00 AM
# checking protected until
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 08:04:01
# 1034
# Insufficient info. Skipping row.

# %%
driver.quit()
