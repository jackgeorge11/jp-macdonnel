# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from time import sleep
import datetime
import pandas as pd
import json
from pygame import mixer
import AppKit
# Out:
# pygame 2.2.0 (SDL 2.0.22, Python 3.9.15)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import (
    NoSuchElementException,
    NoAlertPresentException,
    UnexpectedAlertPresentException,
    ElementClickInterceptedException,
    StaleElementReferenceException,
)
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

options = Options()
# options.headless = True
driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()), options=options
)
driver.set_window_position(0, 0)
driver.set_window_size(1400, 768)

# %%
sa = gspread.service_account(filename="./credentials/jp-macdonnel-b7aa48547774.json")
sh = sa.open("green-lights")
sheet = sh.worksheet("2023-06-16")
master = sh.worksheet("master")
df_master = pd.DataFrame(master.get_all_records())


class InvalidAddressException(Exception):
    "Raised when an address can't be parsed."
    pass


class InvalidStateError(Exception):
    "Raised when an address can't be parsed."
    pass


us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}


def beep_5_times():
    for _ in range(5):
        AppKit.NSBeep()
        sleep(0.2)


class GreenLight:
    def __init__(self, sheet):
        self.sheet = sheet
        self.df = pd.DataFrame(sheet.get_all_records())
        self.filled_df = self.df[
            [
                "Customer Name",
                "First Name",
                "Last Name",
                "Job Title",
                "Work Phone",
                "Email",
                "Address Line 1",
                "City",
                "State",
                "Zip Code",
            ]
        ]
        self.username = None
        self.password = None
        self.logged_in = False
        self.attempts = 0
        self.input_names = {
            "customer_name": "s_1_1_87_0",
            "first_name": "s_1_1_79_0",
            "last_name": "s_1_1_78_0",
            "job_title": "s_1_1_81_0",
            "email": "s_1_1_100_0",
            "work_phone": "s_1_1_83_0",
            "address_line_1": "s_1_1_95_0",
            "city": "s_1_1_96_0",
            "state": "s_1_1_97_0",
            "zip_code": "s_1_1_98_0",
            "acct_team_owner": "s_1_1_91_0",
            "franchise_name": "s_1_1_62_0",
            "primary_opportunity": "s_1_1_72_0",
            "expected_quantity": "s_1_1_73_0",
            "updated": "s_1_1_75_0",
        }
        self.seen_companies = set()
        for item in df_master["Customer Name"].values.tolist():
            self.seen_companies.add(item)
        mixer.init()
        self.alarm = mixer.Sound("driftveil.mp3")

    def parse_address(self, address):
        try:
            split = address.split(",")
            strip = [item.strip() for item in split]
            if len(split) < 5:
                raise InvalidAddressException
            elif len(split) == 5:
                return {
                    "address": strip[0],
                    "city": strip[1],
                    "state": strip[2],
                    "zip_code": strip[4][:5],
                }
            else:
                return {
                    "address": strip[0],
                    "city": strip[-4],
                    "state": strip[-3],
                    "zip_code": strip[-1][:5],
                }
        except:
            print("Couldn't parse address. Skipping Row.")
            raise InvalidAddressException

    def parse_state(self, state):
        try:
            return us_state_to_abbrev[state]
        except:
            print("Couldn't convert state to ISO. Skipping Row.")
            raise InvalidStateError

    def attempt(self, callback):
        if self.attempts >= 50:
            self.attempts = 0
            raise Exception("attempt limit exceeded")
        print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
        sleep(1)
        self.attempts += 1
        return callback()

    def get_credentials(self):
        file = open("./credentials/unishipper-credentials.json")
        data = json.load(file)
        self.username = data["username"]
        self.password = data["password"]

    def login(self):
        if not self.username or not self.password:
            self.get_credentials()
        driver.get("http://uone.unishippers.com")
        sleep(3)
        try:
            input_username = driver.find_element(By.ID, "s_swepi_1")
            input_password = driver.find_element(By.ID, "s_swepi_2")
            input_username.send_keys(self.username)
            input_password.send_keys(self.password)
            button_login = driver.find_element(By.ID, "s_swepi_22")
            button_login.click()
            self.attempts = 0
        except NoSuchElementException:
            if (
                "The server you are trying to access is either busy or experiencing difficulties."
                in driver.find_element(By.TAG_NAME, "body").text
            ):
                sleep(5)
                self.attempt(self.login)
            else:
                self.attempt(self.login)

    def open_leads_tab(self):
        print("opening leads tab")
        self.attempts = 45 if self.attempts == 0 else self.attempts
        try:
            applet = driver.find_element(By.CLASS_NAME, "AppletTitle")
            if applet:
                print("applet")
                tabs = driver.find_elements(By.CLASS_NAME, "ui-corner-top")
                for tab in tabs:
                    if tab.text == "Leads":
                        tab.click()
                        self.attempts = 0
                        break
        except NoSuchElementException:
            self.attempt(self.open_leads_tab)

    def start_new_lead(self):
        try:
            button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
            print("starting new lead")
            button.click()
            self.attempts = 0
        except NoSuchElementException:
            self.attempt(self.start_new_lead())

    def cancel_lead(self):
        try:
            button = driver.find_element(By.ID, "s_1_1_113_0_Ctrl")
            print("canceling lead")
            button.click()
            self.attempts = 0
        except NoSuchElementException:
            self.attempt(self.cancel_lead())

    def compare_customer_to_master(self, customer_name):
        return customer_name in self.seen_companies

    def fill(
        self,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
    ):
        print("filling form")

        if not (address and city and state and zip_code):
            raise InvalidAddressException

        inputs = driver.find_elements(By.TAG_NAME, "input")

        for input in inputs:
            try:
                if input.get_attribute("name") == self.input_names["customer_name"]:
                    input.send_keys(customer_name)
                elif input.get_attribute("name") == self.input_names["first_name"]:
                    input.send_keys(first_name)
                elif input.get_attribute("name") == self.input_names["last_name"]:
                    input.send_keys(last_name)
                elif input.get_attribute("name") == self.input_names["job_title"]:
                    if len(job_title) > 30:
                        job_title = job_title[:30]
                    input.send_keys(job_title)
                elif input.get_attribute("name") == self.input_names["email"] and email:
                    input.send_keys(email)
                elif input.get_attribute("name") == self.input_names["work_phone"]:
                    input.send_keys(work_phone)
                elif input.get_attribute("name") == self.input_names["address_line_1"]:
                    if len(address) > 30:
                        address = address[:30]
                    input.send_keys(address)
                elif input.get_attribute("name") == self.input_names["city"]:
                    input.send_keys(city)
                elif input.get_attribute("name") == self.input_names["state"]:
                    input.send_keys(state)
                elif input.get_attribute("name") == self.input_names["zip_code"]:
                    input.send_keys(zip_code)
                elif input.get_attribute("name") == self.input_names["acct_team_owner"]:
                    input.send_keys("JP.MacDonell")
                elif input.get_attribute("name") == self.input_names["franchise_name"]:
                    input.send_keys("Unishippers 1578")
                elif (
                    input.get_attribute("name")
                    == self.input_names["primary_opportunity"]
                ):
                    input.send_keys("US Express")
                elif (
                    input.get_attribute("name") == self.input_names["expected_quantity"]
                ):
                    input.send_keys(100)
                elif (
                    input.get_attribute("name") == self.input_names["updated"]
                ):
                    input.send_keys(datetime.datetime.now().strftime("%-m/%-d/%Y %-I:%M:%S %p"))
            except TypeError as e:
                print(e.__class__.__name__, " while attempting to self.fill")
            except StaleElementReferenceException as e:
                print(e.__class__.__name__, " while attempting to self.fill")

    def accept_alert(self):
        try:
            alert = driver.switch_to.alert
            self.attempts = 45 if self.attempts == 0 else self.attempts
            status = alert.text
            alert.accept()
            print("accepting alert")
            return status
        except NoAlertPresentException:
            return self.attempt(self.accept_alert)

    def check_loading(self):
        html = driver.find_element(By.TAG_NAME, "html")
        if html.get_attribute("class") == "siebui-busy":
            sleep(2.5)
            print("still saving")
            self.check_loading()
        else:
            return

    def save_form(self):
        print("saving form")
        action = ActionChains(driver)
        action.key_down(Keys.CONTROL).send_keys("S").key_up(Keys.CONTROL).perform()
        self.check_loading()

    def check_protection_status(self):
        sleep(0.5)
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_34_0']")
        val = input.get_attribute("value")
        if val == "<Case Required>":
            val = None
        elif val:
            self.attempts = 0
            print("protection status: ", val)
            return val
        else:
            if self.attempts > 10:
                self.attempts = 0
                print("Unable to get protection status")
                return None
            return self.attempt(self.check_protection_status)

    def check_protected_until(self):
        sleep(0.5)
        # fix next line
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_33_0']")
        val = input.get_attribute("value")
        if val:
            self.attempts = 0
            print("protected until: ", val)
            return val
        else:
            if self.attempts > 4:
                self.attempts = 0
                status = "Unable to get protected until date"
                print(status)
                return status
            return self.attempt(self.check_protected_until)

    def update_sales_stage(self):
        print("updating sales stage")
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_92_0']")
        input.clear()
        input.send_keys("Prospect")

    def request_green_light(self):
        print("requesting green light")
        driver.find_element(By.ID, "s_1_1_48_0_Ctrl").click()

    def determine_status_and_protected_until(self):
        self.save_form()
        sleep(0.5)
        print("checking protection status")
        protection_status = self.check_protection_status()
        sleep(0.5)
        print("checking protected until")
        protected_until = self.check_protected_until()
        new_status = ""
        if protection_status and "protected elsewhere" not in protection_status.lower():
            print("not protected elsewhere")
            self.update_sales_stage()
            sleep(0.5)
            self.save_form()
            sleep(0.5)
            self.request_green_light()
            sleep(0.5)
            new_status = self.accept_alert()
            self.attempts = 0
        else:
            new_status = protection_status if protection_status else "Could not determine protection status"
        print(new_status)
        return [new_status, protected_until]

    def update_sheet(self, i, status, protected_until=""):
        today = datetime.datetime.now()
        self.sheet.update(f"K{i+2}", status)
        self.sheet.update(f"L{i+2}", today.strftime("%B %d, %Y – %H:%M:%S"))
        if protected_until:
            self.sheet.update(f"M{i+2}", protected_until)

    def close_popup(self, text="close"):
        for el in driver.find_elements(By.CLASS_NAME, "ui-button-text"):
            if el.text == text:
                el.click()

    def full_form(
        self,
        i,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
        status,
    ):
        try:
            if status:
                print(f"{i}", "\nstatus already exists:", status)
            elif not (customer_name and address):
                status = "Insufficient info. Skipping row."
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            elif self.compare_customer_to_master(customer_name):
                status = f"Customer already exists in master: {customer_name}"
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            else:
                self.seen_companies.add(customer_name)
                print(f"{i}", "\nno status, filling in fields")
                work_phone = (
                    work_phone
                    if work_phone and work_phone != "#ERROR!"
                    else "(310) 000-0000"
                )
                first_name = first_name if first_name else "FakeFirstName"
                last_name = last_name if last_name else "FakeLastName"
                if not (city or state or zip_code):
                    print(
                        "no city or state or zip code. Atempting to parse address.",
                    )
                    parsed = self.parse_address(address)
                    address = parsed["address"]
                    city = parsed["city"]
                    state = parsed["state"]
                    zip_code = parsed["zip_code"]
                sleep(1)
                if not (address or city or state or zip_code):
                    status = "Insufficient address info. Skipping row."
                else:
                    if len(state) > 2:
                        state = self.parse_state(state)
                    self.fill(
                        customer_name,
                        first_name,
                        last_name,
                        job_title,
                        work_phone,
                        email,
                        address,
                        city,
                        state,
                        zip_code,
                    )
                    [
                        status,
                        protected_until,
                    ] = self.determine_status_and_protected_until()
                sleep(0.5)
                self.update_sheet(i, status, protected_until)
                sleep(0.5)
                self.start_new_lead()
        except UnexpectedAlertPresentException as e:
            print(e.__class__.__name__)
            sleep(0.5)
            print("switching to alert")
            alert = driver.switch_to.alert
            print("alert: ", alert.text)
            self.update_sheet(
                i,
                f"UnexpectedAlertPresentException: {alert.text}. \n\nRow may have been skipped.",
            )
            print("unexpected alert; skipping row")
            self.update_sheet(i, "Unexpected alert error; row skipped")
            self.accept_alert()
            self.attempts = 0
        except ElementClickInterceptedException as e:
            print(e.__class__.__name__)
            self.close_popup()
            sleep(0.5)
            status = self.determine_status_and_protected_until()
            self.update_sheet(i, status)
            sleep(0.5)
            self.start_new_lead()
            try:
                self.request_green_light()
            except:
                self.update_sheet(
                    i, "Element Click Intercepted Exception. Row likely skipped."
                )
        except InvalidStateError as e:
            print(e.__class__.__name__)
            self.update_sheet(
                i,
                "Key Error. Unable to convert state name to ISO code. Row likely skipped.",
            )
        except InvalidAddressException as e:
            print(e.__class__.__name__)
            self.update_sheet(i, "Invalid Address. Row likely skipped.")
        except Exception as e:
            beep_5_times()
            ex_type = e.__class__.__name__
            print(ex_type)
            self.skip_row_with_unexpected_exception(i, ex_type)

    def skip_row_with_unexpected_exception(self, i, ex_type):
        print("attempting to skip row due to unexpected exception")
        try:
            sleep(0.5)
            alert = driver.switch_to.alert
            self.update_sheet(
                i,
                f"Unexpected exception: {ex_type}; with alert present: {alert.text}. \n\nRow likely skipped.",
            )
            self.accept_alert()
            sleep(0.5)
            self.cancel_lead()
            sleep(0.5)
            self.start_new_lead()
        except Exception as e:
            print(e.__class__.__name__)
            raise e

    def iterate(self, start=0, end=None):
        # changed unishippers to self might need to change back
        df = self.df
        if end:
            df = df[start:end]
        for (
            i,
            customer_name,
            first_name,
            last_name,
            job_title,
            work_phone,
            email,
            address,
            city,
            state,
            zip_code,
            status,
            updated,
            protected_until,
        ) in df.itertuples():
            print(datetime.datetime.now().strftime("%H:%M:%S"))
            self.full_form(
                i,
                customer_name,
                first_name,
                last_name,
                job_title,
                work_phone,
                email,
                address,
                city,
                state,
                zip_code,
                status,
            )
            print("\n\n")

    def iterate_with_alarm(self):
        try:
            self.iterate()
        except Exception as e:
            self.alarm.play()
            raise e


unishippers = GreenLight(sheet)

# %%
unishippers.login()
# Out:
# attempting login for the 1 time

# %%
unishippers.open_leads_tab()
# Out:
# opening leads tab
# applet

# %%
unishippers.start_new_lead()
# Out:
# starting new lead
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
# ...
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=215'>216</a> try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=216'>217</a>     button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=217'>218</a>     print("starting new lead")
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:857, in WebDriver.find_element(self, by, value)
#     855     value = '[name="%s"]' % value
# --> 857 return self.execute(Command.FIND_ELEMENT, {
#     858     'using': by,
#     859     'value': value})['value']
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="s_1_1_111_0_Ctrl"]"}
#   (Session info: chrome=114.0.5735.133)
# Stacktrace:
# 0   chromedriver                        0x0000000102663f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010265c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001022a0d68 chromedriver + 281960
# 3   chromedriver                        0x00000001022dbfc8 chromedriver + 524232
# 4   chromedriver                        0x0000000102312c58 chromedriver + 748632
# 5   chromedriver                        0x00000001022cff1c chromedriver + 474908
# 6   chromedriver                        0x00000001022d0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010262559c chromedriver + 3970460
# 8   chromedriver                        0x00000001026296f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010262f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010262a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001026021c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000102646088 chromedriver + 4104328
# 13  chromedriver                        0x00000001026461e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000102655f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a3d0d240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a3d08024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> unishippers.start_new_lead()
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=219'>220</a>     self.attempts = 0
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=220'>221</a> except NoSuchElementException:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=221'>222</a>     self.attempt(self.start_new_lead())
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=219'>220</a>     self.attempts = 0
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=220'>221</a> except NoSuchElementException:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=221'>222</a>     self.attempt(self.start_new_lead())
#
#     [... skipping similar frames: GreenLight.start_new_lead at line 222 (476 times)]
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.start_new_lead(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=219'>220</a>     self.attempts = 0
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=220'>221</a> except NoSuchElementException:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=221'>222</a>     self.attempt(self.start_new_lead())
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb Cell 6 in GreenLight.attempt(self, callback)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=162'>163</a>     self.attempts = 0
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=163'>164</a>     raise Exception("attempt limit exceeded")
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=164'>165</a> print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=165'>166</a> sleep(1)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/request_green_light.ipynb#W5sZmlsZQ%3D%3D?line=166'>167</a> self.attempts += 1
#
# AttributeError: 'NoneType' object has no attribute '__name__'

# %%
unishippers.iterate_with_alarm()
# unishippers.iterate()
# Out:
# 21:45:20
# 0
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 1
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 2
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 3
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 4
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 5
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 6
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 7
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 8
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 9
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 10
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 11
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 12
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 13
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 14
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 15
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 16
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 17
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 18
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 19
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 20
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 21
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 22
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 23
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 24
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 25
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 26
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 27
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 28
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 29
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 30
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 31
# status already exists: Customer already exists in master: BioCalth International
#
#
#
# 21:45:20
# 32
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 33
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 34
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 35
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 36
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 37
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 38
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 39
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 40
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 41
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 42
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 43
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 44
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 45
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 46
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 47
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 48
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 49
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 50
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 51
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 52
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 53
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 54
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 55
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 56
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 57
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 58
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 59
# status already exists: Customer already exists in master: Concentric Analgesics
#
#
#
# 21:45:20
# 60
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 61
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 62
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 63
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 64
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 65
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 66
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 67
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 68
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 69
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 70
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 71
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 72
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 73
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 74
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 75
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 76
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 77
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 78
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 79
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 80
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 81
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 82
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 83
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 84
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 85
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 86
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 87
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 88
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 89
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 90
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 91
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 92
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 93
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 94
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 95
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 96
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 97
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 98
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 99
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 100
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 101
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 102
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 103
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 104
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 105
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 106
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 107
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 108
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 109
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 110
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 111
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 112
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 113
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 114
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 115
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 116
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 117
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 118
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 119
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 120
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 121
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 122
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 123
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 124
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 125
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 126
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 127
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 128
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 129
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 130
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 131
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 132
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 133
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 134
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 135
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 136
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 137
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 138
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 139
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 140
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 141
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 142
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 143
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 144
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 145
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 146
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 147
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 148
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 149
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 150
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 151
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 152
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 153
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 154
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 155
# status already exists: skipped
#
#
#
# 21:45:20
# 156
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 157
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 158
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 159
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 160
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 161
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 162
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 163
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 164
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 165
# status already exists: Customer already exists in master: Novotech Nutrition
#
#
#
# 21:45:20
# 166
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 167
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 168
# status already exists: Customer already exists in master: Nutrawerx
#
#
#
# 21:45:20
# 169
# status already exists: Customer already exists in master: Nutrient Innovations
#
#
#
# 21:45:20
# 170
# status already exists: Customer already exists in master: Nutrition53
#
#
#
# 21:45:20
# 171
# status already exists: Customer already exists in master: Nutritional Engineering
#
#
#
# 21:45:20
# 172
# status already exists: Customer already exists in master: NWC Naturals
#
#
#
# 21:45:20
# 173
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 174
# status already exists: Customer already exists in master: Oleavicin
#
#
#
# 21:45:20
# 175
# status already exists: Customer already exists in master: Omax Health
#
#
#
# 21:45:20
# 176
# status already exists: Customer already exists in master: Ossium Health
#
#
#
# 21:45:20
# 177
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 178
# status already exists: Customer already exists in master: Pacific Health Sciences
#
#
#
# 21:45:20
# 179
# status already exists: Customer already exists in master: Pacific Manufacturing
#
#
#
# 21:45:20
# 180
# status already exists: Customer already exists in master: Pacific Manufacturing and Design
#
#
#
# 21:45:20
# 181
# status already exists: Customer already exists in master: Pelorus Equity Group
#
#
#
# 21:45:20
# 182
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 183
# status already exists: Customer already exists in master: ProCann
#
#
#
# 21:45:20
# 184
# status already exists: Customer already exists in master: Protekt Products
#
#
#
# 21:45:20
# 185
# status already exists: Customer already exists in master: Provida Life Sciences
#
#
#
# 21:45:20
# 186
# status already exists: Customer already exists in master: Pure Science International
#
#
#
# 21:45:20
# 187
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 188
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 189
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 190
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 191
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 192
# status already exists: Customer already exists in master: Rejuvenation Therapeutics
#
#
#
# 21:45:20
# 193
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 194
# status already exists: Customer already exists in master: Resonate Blends
#
#
#
# 21:45:20
# 195
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 196
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 197
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 198
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 199
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 200
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 201
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 202
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 203
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 204
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 205
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 206
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 207
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 208
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 209
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 210
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 211
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 212
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 213
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 214
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 215
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 216
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 217
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 218
# status already exists: Customer already exists in master: Sunday Scaries
#
#
#
# 21:45:20
# 219
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 220
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 221
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 222
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 223
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 224
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 225
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 226
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 227
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 228
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 229
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 230
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 231
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 232
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 233
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 234
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 235
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 236
# status already exists: Customer already exists in master: True Nutrition
#
#
#
# 21:45:20
# 237
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 238
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 239
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 240
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 241
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 242
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 243
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 244
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 245
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 246
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 247
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 248
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 249
# status already exists: Customer already exists in master: VitaMedica
#
#
#
# 21:45:20
# 250
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 251
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 252
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 253
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 254
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 255
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 256
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 257
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 258
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 259
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 260
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 261
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 262
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 263
# status already exists: Customer already exists in master: PNI Sensor
#
#
#
# 21:45:20
# 264
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 265
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 266
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 267
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 268
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 269
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 270
# status already exists: Value too long for field 'City' (maximum size 20).(SBL-DAT-00235)
#
#
#
#
# 21:45:20
# 271
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 272
# status already exists: Customer already exists in master: S&K Theatrical Draperies
#
#
#
# 21:45:20
# 273
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 274
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 275
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 276
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 277
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 278
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 279
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 280
# status already exists: Customer already exists in master: Heat Factory
#
#
#
# 21:45:20
# 281
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 282
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 283
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 284
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 285
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 286
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 287
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 288
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 289
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 290
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 291
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 292
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 293
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 294
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 295
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 296
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 297
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 298
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 299
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 300
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 301
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 302
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 303
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 304
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 305
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 306
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 307
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 308
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 309
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 310
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 311
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 312
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 313
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 314
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 315
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 316
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 317
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 318
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 319
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 320
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 321
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 322
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 323
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 324
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 325
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 326
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 327
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 328
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 329
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 330
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 331
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 332
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 333
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 334
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 335
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 336
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 337
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 338
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 339
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 21:45:20
# 340
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 341
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 342
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 343
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 344
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 345
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 346
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 347
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 348
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 349
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 350
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 351
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 352
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 353
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 354
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 355
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 356
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 357
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 358
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 359
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 360
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 361
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 362
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 363
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 364
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 365
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 366
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 367
# status already exists: Customer already exists in master: The Lab
#
#
#
# 21:45:20
# 368
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 369
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 370
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 371
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 372
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 373
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 374
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 375
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 376
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 377
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 378
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 379
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 380
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 381
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 382
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 383
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 384
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 385
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 386
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 387
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 388
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 389
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 390
# status already exists: Customer already exists in master: Southern California Packaging Equipment
#
#
#
# 21:45:20
# 391
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 392
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 393
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 394
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 395
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 396
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 397
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 398
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 399
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 400
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 401
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 402
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 403
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 404
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 405
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 406
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 407
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 408
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 409
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 410
# status already exists: Customer already exists in master: Pacific Paper
#
#
#
# 21:45:20
# 411
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 412
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 413
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 414
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 415
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 416
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 417
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 418
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 419
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 420
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 421
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 422
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 423
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 424
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 425
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 426
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 427
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 428
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 429
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 430
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 431
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 432
# status already exists: Customer already exists in master: Vertical Construction
#
#
#
# 21:45:20
# 433
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 434
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 435
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 436
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 437
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 438
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 439
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 440
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 441
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 442
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 443
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 444
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 445
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 446
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 447
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 448
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 449
# status already exists: Key Error. Unable to convert state name to ISO code. Row likely skipped.
#
#
#
# 21:45:20
# 450
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 451
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 452
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 453
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 454
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 455
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 456
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 457
# status already exists: Protected Elsewhere
#
#
#
# 21:45:20
# 458
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 459
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 460
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 461
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 462
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 463
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 464
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 465
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 466
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 467
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 468
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 469
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 470
# status already exists: Customer already exists in master: Rescue Dog Wines
#
#
#
# 21:45:20
# 471
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 472
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 473
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 474
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 475
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 476
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 477
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 478
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 479
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 480
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 481
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 482
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 483
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 484
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 485
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 486
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 487
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 488
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 489
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 490
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 491
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 492
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 493
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 494
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 495
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 496
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 497
# status already exists: Customer already exists in master: DaMar Plastics
#
#
#
# 21:45:20
# 498
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 499
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 500
# status already exists: Insufficient info. Skipping row.
#
#
#
# 21:45:20
# 501
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 21:45:20
# 502
# ...
#
#
#
# 22:49:47
# 947
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:50:07
# 948
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:50:08
# 949
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:50:28
# 950
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:50:49
# 951
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:51:09
# 952
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:51:30
# 953
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:51:30
# 954
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:51:50
# 955
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:52:13
# 956
# Customer already exists in master: The Signworks
#
#
#
# 22:52:13
# 957
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:52:34
# 958
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:52:55
# 959
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:53:15
# 960
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:53:16
# 961
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:53:16
# 962
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:53:36
# 963
# Customer already exists in master: Tortuga
#
#
#
# 22:53:37
# 964
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:53:57
# 965
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# checking protection status
# protection status:  Protected Elsewhere
# checking protected until
# protected until:  6/16/2023 12:00:00 AM
# Protected Elsewhere
# starting new lead
#
#
#
# 22:54:15
# 966
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:54:16
# 967
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:54:36
# 968
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:54:56
# 969
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:55:21
# 970
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:55:41
# 971
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:55:42
# 972
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:56:02
# 973
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:56:23
# 974
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected Elsewhere
# checking protected until
# protected until:  6/16/2023 12:00:00 AM
# Protected Elsewhere
# starting new lead
#
#
#
# 22:56:36
# 975
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:56:56
# 976
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:57:16
# 977
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:57:37
# 978
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:57:37
# 979
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:57:58
# 980
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 22:57:58
# 981
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:58:19
# 982
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:58:41
# 983
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:59:02
# 984
# Insufficient info. Skipping row.
#
#
#
# 22:59:02
# 985
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:59:22
# 986
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 22:59:42
# 987
# Insufficient info. Skipping row.
#
#
#
# 22:59:43
# 988
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 23:00:06
# 989
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 23:00:07
# 990
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected
# checking protected until
# protected until:  6/24/2023 12:00:00 AM
# not protected elsewhere
# updating sales stage
# saving form
# still saving
# requesting green light
# accepting alert
# Your request will be sent to UPS in the next batch(SBL-EXL-00151)
# starting new lead
#
#
#
# 23:00:27
# 991
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# checking protection status
# protection status:  Protected Elsewhere
# checking protected until
# protected until:  6/16/2023 12:00:00 AM
# Protected Elsewhere
# starting new lead

# %%
unishippers.alarm.fadeout(1200)

# %%
unishippers.cancel_lead()
unishippers.start_new_lead()

# %%
driver.quit()

# %%
print(datetime.datetime.now().strftime("%-m/%-d/%Y %-I:%M:%S %p"))
