# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from time import sleep
import datetime
import pandas as pd
import json
from pygame import mixer
import AppKit
import usaddress
import pprint

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.common.exceptions import (
    NoSuchElementException,
    NoAlertPresentException,
    UnexpectedAlertPresentException,
    ElementClickInterceptedException,
    StaleElementReferenceException,
)
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
options = Options()
# options.headless = True
driver = webdriver.Chrome(
    service=Service(ChromeDriverManager().install()), options=options
)
driver.set_window_position(0, 0)
driver.set_window_size(1400, 768)

# %%
sa = gspread.service_account(filename="../credentials/jp-macdonnel-b7aa48547774.json")
sh = sa.open("green-lights")
sheet = sh.worksheet("2023-07-22")
master = sh.worksheet("master")
df_master = pd.DataFrame(master.get_all_records())


class InvalidAddressException(Exception):
    "Raised when an address can't be parsed."
    ...


class InvalidStateError(Exception):
    "Raised when state can't be converted to ISO format."
    ...


us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}


def beep_5_times():
    for _ in range(5):
        AppKit.NSBeep()
        sleep(0.2)


class GreenLight:
    def __init__(self, sheet):
        self.sheet = sheet
        self.df = pd.DataFrame(sheet.get_all_records())
        self.filled_df = self.df[
            [
                "Customer Name",
                "First Name",
                "Last Name",
                "Job Title",
                "Work Phone",
                "Email",
                "Address Line 1",
                "City",
                "State",
                "Zip Code",
            ]
        ]
        self.username = None
        self.password = None
        self.logged_in = False
        self.attempts = 0
        self.input_names = {
            "customer_name": "s_1_1_87_0",
            "first_name": "s_1_1_79_0",
            "last_name": "s_1_1_78_0",
            "job_title": "s_1_1_81_0",
            "email": "s_1_1_100_0",
            "work_phone": "s_1_1_83_0",
            "address_line_1": "s_1_1_95_0",
            "city": "s_1_1_96_0",
            "state": "s_1_1_97_0",
            "zip_code": "s_1_1_98_0",
            "acct_team_owner": "s_1_1_91_0",
            "franchise_name": "s_1_1_62_0",
            "primary_opportunity": "s_1_1_72_0",
            "expected_quantity": "s_1_1_73_0",
            "updated": "s_1_1_75_0",
        }
        self.seen_companies = set()
        for item in df_master["Customer Name"].values.tolist():
            self.seen_companies.add(item)
        mixer.init()
        self.alarm = mixer.Sound("../driftveil.mp3")

    def parse_address(self, address):
        try:
            parsed = usaddress.tag(
                address.replace("United States, ", "")
                .replace(", United States", "")
                .replace("United States", "")
            )[0]
            return {
                "address": " ".join(
                    (
                        list(
                            filter(
                                lambda x: x is not None,
                                [
                                    parsed.get("BuildingName", None),
                                    parsed.get("AddressNumber", None),
                                    parsed.get("StreetNamePreDirectional", None),
                                    parsed.get("StreetName", None),
                                    parsed.get("StreetNamePostType", None),
                                ],
                            )
                        )
                    )
                ),
                "city": parsed["PlaceName"],
                "state": parsed["StateName"],
                "zip_code": parsed["ZipCode"],
            }
        except:
            print("Couldn't parse address. Skipping Row.")
            raise InvalidAddressException

    def parse_state(self, state):
        try:
            return us_state_to_abbrev[state]
        except:
            print("Couldn't convert state to ISO. Skipping Row.")
            raise InvalidStateError

    def attempt(self, callback):
        if self.attempts >= 50:
            self.attempts = 0
            raise Exception("attempt limit exceeded")
        print(f"attempting {callback.__name__} for the {self.attempts + 1} time")
        sleep(1)
        self.attempts += 1
        return callback()

    def get_credentials(self):
        file = open("../credentials/unishipper-credentials.json")
        data = json.load(file)
        self.username = data["username"]
        self.password = data["password"]

    def login(self):
        if not self.username or not self.password:
            self.get_credentials()
        driver.get("http://uone.unishippers.com")
        sleep(3)
        try:
            input_username = driver.find_element(By.ID, "s_swepi_1")
            input_password = driver.find_element(By.ID, "s_swepi_2")
            input_username.send_keys(self.username)
            input_password.send_keys(self.password)
            button_login = driver.find_element(By.ID, "s_swepi_22")
            button_login.click()
            self.attempts = 0
        except NoSuchElementException:
            if self.attempts > 3:
                print("cant login. try again")
                return
            if (
                "The server you are trying to access is either busy or experiencing difficulties."
                in driver.find_element(By.TAG_NAME, "body").text
            ):
                sleep(5)
                self.attempt(self.login)
            else:
                self.attempt(self.login)

    def open_leads_tab(self):
        print("opening leads tab")
        self.attempts = 45 if self.attempts == 0 else self.attempts
        try:
            applet = driver.find_element(By.CLASS_NAME, "AppletTitle")
            if applet:
                print("applet")
                tabs = driver.find_elements(By.CLASS_NAME, "ui-corner-top")
                for tab in tabs:
                    if tab.text == "Leads":
                        tab.click()
                        self.attempts = 0
                        break
        except NoSuchElementException:
            self.attempt(self.open_leads_tab)

    def start_new_lead(self):
        try:
            button = driver.find_element(By.ID, "s_1_1_111_0_Ctrl")
            print("starting new lead")
            button.click()
            self.attempts = 0
        except NoSuchElementException:
            self.attempt(self.start_new_lead())

    def cancel_lead(self):
        try:
            button = driver.find_element(By.ID, "s_1_1_113_0_Ctrl")
            print("canceling lead")
            button.click()
            self.attempts = 0
        except NoSuchElementException:
            self.attempt(self.cancel_lead())

    def compare_customer_to_master(self, customer_name):
        return customer_name in self.seen_companies

    def fill(
        self,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
    ):
        print("filling form")

        if not (address and city and state and zip_code):
            raise InvalidAddressException

        inputs = driver.find_elements(By.TAG_NAME, "input")

        for input in inputs:
            try:
                if input.get_attribute("name") == self.input_names["customer_name"]:
                    input.send_keys(customer_name)
                elif input.get_attribute("name") == self.input_names["first_name"]:
                    input.send_keys(first_name)
                elif input.get_attribute("name") == self.input_names["last_name"]:
                    input.send_keys(last_name)
                elif input.get_attribute("name") == self.input_names["job_title"]:
                    if len(job_title) > 30:
                        job_title = job_title[:30]
                    input.send_keys(job_title)
                elif input.get_attribute("name") == self.input_names["email"] and email:
                    input.send_keys(email)
                elif input.get_attribute("name") == self.input_names["work_phone"]:
                    input.send_keys(work_phone)
                elif input.get_attribute("name") == self.input_names["address_line_1"]:
                    if len(address) > 30:
                        address = address[:30]
                    input.send_keys(address)
                elif input.get_attribute("name") == self.input_names["city"]:
                    input.send_keys(city)
                elif input.get_attribute("name") == self.input_names["state"]:
                    input.send_keys(state)
                elif input.get_attribute("name") == self.input_names["zip_code"]:
                    input.send_keys(zip_code)
                elif input.get_attribute("name") == self.input_names["acct_team_owner"]:
                    input.send_keys("JP.MacDonell")
                elif input.get_attribute("name") == self.input_names["franchise_name"]:
                    input.send_keys("Unishippers 1578")
                elif (
                    input.get_attribute("name")
                    == self.input_names["primary_opportunity"]
                ):
                    input.send_keys("US Express")
                elif (
                    input.get_attribute("name") == self.input_names["expected_quantity"]
                ):
                    input.send_keys(100)
                elif input.get_attribute("name") == self.input_names["updated"]:
                    input.send_keys(
                        datetime.datetime.now().strftime("%-m/%-d/%Y %-I:%M:%S %p")
                    )
            except TypeError as e:
                print(e.__class__.__name__, " while attempting to self.fill")
            except StaleElementReferenceException as e:
                print(e.__class__.__name__, " while attempting to self.fill")

    def accept_alert(self):
        try:
            alert = driver.switch_to.alert
            self.attempts = 45 if self.attempts == 0 else self.attempts
            status = alert.text
            alert.accept()
            print("accepting alert")
            return status
        except NoAlertPresentException:
            return self.attempt(self.accept_alert)

    def check_loading(self):
        html = driver.find_element(By.TAG_NAME, "html")
        if html.get_attribute("class") == "siebui-busy":
            sleep(2.5)
            print("still saving")
            self.check_loading()
        else:
            return

    def save_form(self):
        print("saving form")
        action = ActionChains(driver)
        action.key_down(Keys.CONTROL).send_keys("S").key_up(Keys.CONTROL).perform()
        self.check_loading()

    def check_protection_status(self):
        print("checking protection status")
        sleep(0.5)
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_34_0']")
        val = input.get_attribute("value")
        if val == "<Case Required>":
            val = None
        elif val:
            self.attempts = 0
            print("protection status: ", val)
            return val
        else:
            if self.attempts > 10:
                self.attempts = 0
                print("Unable to get protection status")
                return None
            return self.attempt(self.check_protection_status)

    def check_protected_until(self):
        sleep(0.5)
        # fix next line
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_33_0']")
        val = input.get_attribute("value")
        if val:
            self.attempts = 0
            print("protected until: ", val)
            return val
        else:
            if self.attempts > 4:
                self.attempts = 0
                status = "Unable to get protected until date"
                print(status)
                return status
            return self.attempt(self.check_protected_until)

    def update_sales_stage(self):
        print("updating sales stage")
        input = driver.find_element(By.CSS_SELECTOR, "input[name='s_1_1_92_0']")
        input.clear()
        input.send_keys("Prospect")

    def request_green_light(self):
        print("requesting green light")
        driver.find_element(By.ID, "s_1_1_48_0_Ctrl").click()

    def determine_status_and_protected_until(self):
        self.save_form()
        sleep(0.5)
        print("checking protection status")
        protection_status = self.check_protection_status()
        sleep(0.5)
        print("checking protected until")
        protected_until = self.check_protected_until()
        new_status = ""
        if protection_status and "protected elsewhere" not in protection_status.lower():
            print("not protected elsewhere")
            self.update_sales_stage()
            sleep(0.5)
            self.save_form()
            sleep(0.5)
            self.request_green_light()
            sleep(0.5)
            new_status = self.accept_alert()
            self.attempts = 0
        else:
            new_status = (
                protection_status
                if protection_status
                else "Could not determine protection status"
            )
        print(new_status)
        return [new_status, protected_until]

    def update_sheet(self, i, status, protected_until=""):
        today = datetime.datetime.now()
        self.sheet.update(f"K{i+2}", status)
        self.sheet.update(f"L{i+2}", today.strftime("%B %d, %Y – %H:%M:%S"))
        if protected_until:
            self.sheet.update(f"M{i+2}", protected_until)

    def close_popup(self, text="close"):
        for el in driver.find_elements(By.CLASS_NAME, "ui-button-text"):
            if el.text == text:
                el.click()

    def full_form(
        self,
        i,
        customer_name,
        first_name,
        last_name,
        job_title,
        work_phone,
        email,
        address,
        city,
        state,
        zip_code,
        status,
    ):
        try:
            if status:
                print(f"{i}", "\nstatus already exists:", status)
            elif not (customer_name and address):
                status = "Insufficient info. Skipping row."
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            elif self.compare_customer_to_master(customer_name):
                status = f"Customer already exists in master: {customer_name}"
                print(f"{i}", f"\n{status}")
                self.update_sheet(i, status)
            else:
                self.seen_companies.add(customer_name)
                print(f"{i}", "\nno status, filling in fields")
                work_phone = (
                    work_phone
                    if work_phone and work_phone != "#ERROR!"
                    else "(310) 000-0000"
                )
                first_name = first_name if first_name else "FakeFirstName"
                last_name = last_name if last_name else "FakeLastName"
                if not (city or state or zip_code):
                    print(
                        "no city or state or zip code. Atempting to parse address.",
                    )
                    parsed = self.parse_address(address)
                    address = parsed["address"]
                    city = parsed["city"]
                    state = parsed["state"]
                    zip_code = parsed["zip_code"]
                sleep(1)
                if not (address or city or state or zip_code):
                    status = "Insufficient address info. Skipping row."
                else:
                    if len(state) > 2:
                        state = self.parse_state(state)
                    self.fill(
                        customer_name,
                        first_name,
                        last_name,
                        job_title,
                        work_phone,
                        email,
                        address,
                        city,
                        state,
                        zip_code,
                    )
                    status, protected_until = self.determine_status_and_protected_until()
                sleep(0.5)
                self.update_sheet(i, status, protected_until)
                sleep(0.5)
                self.start_new_lead()
        except UnexpectedAlertPresentException as e:
            print(e.__class__.__name__)
            print("switching to alert")
            print(e.msg)
            self.update_sheet(
                i,
                f"UnexpectedAlertPresentException: {e.msg}. \n\nWill still attempt to request green light, however row may have been skipped.",
            )
            print("moving on to next lead")
        except ElementClickInterceptedException as e:
            print(e.__class__.__name__)
            self.close_popup()
            sleep(0.5)
            status = self.determine_status_and_protected_until()
            self.update_sheet(i, status)
            sleep(0.5)
            self.start_new_lead()
            try:
                self.request_green_light()
            except:
                self.update_sheet(
                    i, "Element Click Intercepted Exception. Row likely skipped."
                )
        except InvalidStateError as e:
            print(e.__class__.__name__)
            self.update_sheet(
                i,
                "Key Error. Unable to convert state name to ISO code. Row likely skipped.",
            )
        except InvalidAddressException as e:
            print(e.__class__.__name__)
            self.update_sheet(i, "Invalid Address. Row likely skipped.")
        except Exception as e:
            beep_5_times()
            ex_type = e.__class__.__name__
            print(ex_type)
            self.skip_row_with_unexpected_exception(i, ex_type)

    def skip_row_with_unexpected_exception(self, i, ex_type):
        print("attempting to skip row due to unexpected exception")
        try:
            sleep(0.5)
            alert = driver.switch_to.alert
            self.update_sheet(
                i,
                f"Unexpected exception: {ex_type}; with alert present: {alert.text}. \n\nRow likely skipped.",
            )
            self.accept_alert()
            sleep(0.5)
            self.cancel_lead()
            sleep(0.5)
            self.start_new_lead()
        except Exception as e:
            print(e.__class__.__name__)
            raise e

    def iterate(self, start=0, end=None):
        # changed unishippers to self might need to change back
        df = self.df
        if end:
            df = df[start:end]
        for (
            i,
            customer_name,
            first_name,
            last_name,
            job_title,
            work_phone,
            email,
            address,
            city,
            state,
            zip_code,
            status,
            updated,
            protected_until,
        ) in df.itertuples():
            print(datetime.datetime.now().strftime("%H:%M:%S"))
            self.full_form(
                i,
                customer_name,
                first_name,
                last_name,
                job_title,
                work_phone,
                email,
                address,
                city,
                state,
                zip_code,
                status,
            )
            print("\n\n")

    def iterate_with_alarm(self):
        try:
            self.iterate()
        except Exception as e:
            self.alarm.play()
            raise e


unishippers = GreenLight(sheet)

# %%
unishippers.login()
# Out:
# attempting login for the 1 time

# %%
unishippers.open_leads_tab()
# Out:
# opening leads tab
# applet

# %%
unishippers.start_new_lead()
# Out:
# starting new lead

# %%
unishippers.iterate_with_alarm()
# Out:
# 13:50:14
# 0
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 13:50:14
# 1
# status already exists: Protected Elsewhere
#
#
#
# 13:50:14
# 2
# status already exists: Customer already exists in master: Honda of Weatherford
#
#
#
# 13:50:14
# 3
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 4
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 5
# status already exists: Row skipped.
#
#
#
# 13:50:14
# 6
# status already exists: Customer already exists in master: 55Haitao Group
#
#
#
# 13:50:14
# 7
# status already exists: Customer already exists in master: Preston's Compounding Pharmacy
#
#
#
# 13:50:14
# 8
# status already exists: Customer already exists in master: Alliance for Pharmacy Compounding
#
#
#
# 13:50:14
# 9
# status already exists: Protected Elsewhere
#
#
#
# 13:50:14
# 10
# status already exists: Customer already exists in master: Absolute Usa
#
#
#
# 13:50:14
# 11
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 12
# status already exists: Customer already exists in master: Adina Reyter
#
#
#
# 13:50:14
# 13
# status already exists: Customer already exists in master: AESP
#
#
#
# 13:50:14
# 14
# status already exists: Customer already exists in master: AESP
#
#
#
# 13:50:14
# 15
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 16
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 17
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 18
# status already exists: Customer already exists in master: AirMark Corporation
#
#
#
# 13:50:14
# 19
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 20
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 21
# status already exists: Customer already exists in master: Arcade Lane Compounding Pharmacy
#
#
#
# 13:50:14
# 22
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 23
# status already exists: Customer already exists in master: Observint Technologies
#
#
#
# 13:50:14
# 24
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 25
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 26
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 27
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 28
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 29
# status already exists: Customer already exists in master: Alvarado Street Bakery
#
#
#
# 13:50:14
# 30
# status already exists: Protected Elsewhere
#
#
#
# 13:50:14
# 31
# status already exists: Customer already exists in master: American Fireglass
#
#
#
# 13:50:14
# 32
# status already exists: Customer already exists in master: AMP Research | A RealTruck Company
#
#
#
# 13:50:14
# 33
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 34
# status already exists: Customer already exists in master: Angier Family Pharmacy
#
#
#
# 13:50:14
# 35
# status already exists: Protected Elsewhere
#
#
#
# 13:50:14
# 36
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 37
# status already exists: Customer already exists in master: Annie's Apothecary
#
#
#
# 13:50:14
# 38
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 39
# status already exists: Customer already exists in master: APExBIO Technology LLC
#
#
#
# 13:50:14
# 40
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 41
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 42
# status already exists: Customer already exists in master: ARCONA, Inc.
#
#
#
# 13:50:14
# 43
# status already exists: Customer already exists in master: ARCONA, Inc.
#
#
#
# 13:50:14
# 44
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 45
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 46
# status already exists: Customer already exists in master: ASRV
#
#
#
# 13:50:14
# 47
# status already exists: Customer already exists in master: Assembly
#
#
#
# 13:50:14
# 48
# status already exists: Customer already exists in master: Atlas Professional Services
#
#
#
# 13:50:14
# 49
# status already exists: Customer already exists in master: ATRA FORM
#
#
#
# 13:50:14
# 50
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 51
# status already exists: Customer already exists in master: Audubon Bioscience
#
#
#
# 13:50:14
# 52
# status already exists: Customer already exists in master: Avaz Media
#
#
#
# 13:50:14
# 53
# status already exists: Customer already exists in master: Aventus Health
#
#
#
# 13:50:14
# 54
# status already exists: Customer already exists in master: B2BMD
#
#
#
# 13:50:14
# 55
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 56
# status already exists: Customer already exists in master: balena
#
#
#
# 13:50:14
# 57
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 58
# status already exists: Customer already exists in master: Ballard Industrial
#
#
#
# 13:50:14
# 59
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 60
# status already exists: Customer already exists in master: Band Pro Film & Digital, Inc.
#
#
#
# 13:50:14
# 61
# status already exists: Customer already exists in master: Bank's Apothecary Specialty Pharmacy
#
#
#
# 13:50:14
# 62
# status already exists: Customer already exists in master: Barefoot Coffee
#
#
#
# 13:50:14
# 63
# status already exists: Customer already exists in master: Barth Dental Laboratory
#
#
#
# 13:50:14
# 64
# status already exists: Customer already exists in master: Barton Perreira
#
#
#
# 13:50:14
# 65
# status already exists: Customer already exists in master: Barton Perreira
#
#
#
# 13:50:14
# 66
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 67
# status already exists: Customer already exists in master: Beach Riot LLC
#
#
#
# 13:50:14
# 68
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 69
# status already exists: Invalid Address. Row likely skipped.
#
#
#
# 13:50:14
# 70
# status already exists: Customer already exists in master: Belmar Pharma Solutions
#
#
#
# 13:50:14
# 71
# status already exists: Customer already exists in master: Benasource Rx Consulting Services
#
#
#
# 13:50:14
# 72
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 73
# status already exists: Customer already exists in master: BendPak Inc.
#
#
#
# 13:50:14
# 74
# status already exists: Protected Elsewhere
#
#
#
# 13:50:14
# 75
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 76
# status already exists: Customer already exists in master: Big Game
#
#
#
# 13:50:14
# 77
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 78
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 79
# status already exists: Customer already exists in master: BIORAY®
#
#
#
# 13:50:14
# 80
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 81
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 82
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 83
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 84
# status already exists: Customer already exists in master: The Bloedel Reserve
#
#
#
# 13:50:14
# 85
# status already exists: Customer already exists in master: Bloomington Drug
#
#
#
# 13:50:14
# 86
# status already exists: Your request will be sent to UPS in the next batch(SBL-EXL-00151)
#
#
#
# 13:50:14
# 87
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# saving form
# still saving
# UnexpectedAlertPresentException
# switching to alert
# unexpected alert open: {Alert text : [1]Error invoking service 'SetNewLeadStatus', method 'Set_LeadStatus' at step 'Set Dates and Status'.(SBL-BPR-00162)
# [2]This operation is not available for read only field 'ABCD Account Status'.(SBL-DAT-00402)
# }
#   (Session info: chrome=114.0.5735.248)
# unexpected alert; skipping row
#
#
#
# 13:50:26
# 88
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# Couldn't parse address. Skipping Row.
# InvalidAddressException
#
#
#
# 13:50:30
# 89
# no status, filling in fields
# no city or state or zip code. Atempting to parse address.
# filling form
# ElementNotInteractableException
# attempting to skip row due to unexpected exception
# NoAlertPresentException
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.full_form(self, i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=475'>476</a>     state = self.parse_state(state)
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=476'>477</a> self.fill(
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=477'>478</a>     customer_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=478'>479</a>     first_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=479'>480</a>     last_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=480'>481</a>     job_title,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=481'>482</a>     work_phone,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=482'>483</a>     email,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=483'>484</a>     address,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=484'>485</a>     city,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=485'>486</a>     state,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=486'>487</a>     zip_code,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=487'>488</a> )
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=488'>489</a> status, protected_until = self.determine_status_and_protected_until()
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.fill(self, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=294'>295</a> elif input.get_attribute("name") == self.input_names["franchise_name"]:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=295'>296</a>     input.send_keys("Unishippers 1578")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=296'>297</a> elif (
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=297'>298</a>     input.get_attribute("name")
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=298'>299</a>     == self.input_names["primary_opportunity"]
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=299'>300</a> ):
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:223, in WebElement.send_keys(self, *value)
#     221         value = '\n'.join(remote_files)
# --> 223 self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     224               {'text': "".join(keys_to_typing(value)),
#     225                'value': keys_to_typing(value)})
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webelement.py:396, in WebElement._execute(self, command, params)
#     395 params['id'] = self._id
# --> 396 return self._parent.execute(command, params)
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# ElementNotInteractableException: Message: element not interactable
#   (Session info: chrome=114.0.5735.248)
# Stacktrace:
# 0   chromedriver                        0x0000000104573f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010456c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001041b0be8 chromedriver + 281576
# 3   chromedriver                        0x00000001041e62d8 chromedriver + 500440
# 4   chromedriver                        0x00000001041e59f8 chromedriver + 498168
# 5   chromedriver                        0x00000001041e1734 chromedriver + 481076
# 6   chromedriver                        0x0000000104222c58 chromedriver + 748632
# 7   chromedriver                        0x00000001041dff1c chromedriver + 474908
# 8   chromedriver                        0x00000001041e0ef4 chromedriver + 478964
# 9   chromedriver                        0x000000010453559c chromedriver + 3970460
# 10  chromedriver                        0x00000001045396f0 chromedriver + 3987184
# 11  chromedriver                        0x000000010453f5b4 chromedriver + 4011444
# 12  chromedriver                        0x000000010453a2fc chromedriver + 3990268
# 13  chromedriver                        0x00000001045121c0 chromedriver + 3826112
# 14  chromedriver                        0x0000000104556088 chromedriver + 4104328
# 15  chromedriver                        0x00000001045561e0 chromedriver + 4104672
# 16  chromedriver                        0x0000000104565f28 chromedriver + 4169512
# 17  libsystem_pthread.dylib             0x00000001a6af9240 _pthread_start + 148
# 18  libsystem_pthread.dylib             0x00000001a6af4024 thread_start + 8
#
#
# During handling of the above exception, another exception occurred:
#
# NoAlertPresentException                   Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> unishippers.iterate_with_alarm()
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.iterate_with_alarm(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=590'>591</a> except Exception as e:
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=591'>592</a>     self.alarm.play()
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=592'>593</a>     raise e
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.iterate_with_alarm(self)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=587'>588</a> def iterate_with_alarm(self):
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=588'>589</a>     try:
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=589'>590</a>         self.iterate()
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=590'>591</a>     except Exception as e:
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=591'>592</a>         self.alarm.play()
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.iterate(self, start, end)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=554'>555</a> for (
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=555'>556</a>     i,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=556'>557</a>     customer_name,
#    (...)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=568'>569</a>     protected_until,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=569'>570</a> ) in df.itertuples():
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=570'>571</a>     print(datetime.datetime.now().strftime("%H:%M:%S"))
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=571'>572</a>     self.full_form(
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=572'>573</a>         i,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=573'>574</a>         customer_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=574'>575</a>         first_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=575'>576</a>         last_name,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=576'>577</a>         job_title,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=577'>578</a>         work_phone,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=578'>579</a>         email,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=579'>580</a>         address,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=580'>581</a>         city,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=581'>582</a>         state,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=582'>583</a>         zip_code,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=583'>584</a>         status,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=584'>585</a>     )
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=585'>586</a>     print("\n\n")
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.full_form(self, i, customer_name, first_name, last_name, job_title, work_phone, email, address, city, state, zip_code, status)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=527'>528</a> ex_type = e.__class__.__name__
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=528'>529</a> print(ex_type)
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=529'>530</a> self.skip_row_with_unexpected_exception(i, ex_type)
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.skip_row_with_unexpected_exception(self, i, ex_type)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=545'>546</a> except Exception as e:
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=546'>547</a>     print(e.__class__.__name__)
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=547'>548</a>     raise e
#
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 8 in GreenLight.skip_row_with_unexpected_exception(self, i, ex_type)
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=533'>534</a> try:
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=534'>535</a>     sleep(0.5)
# --> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=535'>536</a>     alert = driver.switch_to.alert
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=536'>537</a>     self.update_sheet(
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=537'>538</a>         i,
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=538'>539</a>         f"Unexpected exception: {ex_type}; with alert present: {alert.text}. \n\nRow likely skipped.",
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=539'>540</a>     )
#     <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#W6sZmlsZQ%3D%3D?line=540'>541</a>     self.accept_alert()
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/switch_to.py:56, in SwitchTo.alert(self)
#      47 """
#      48 Switches focus to an alert on the page.
#      49
#    (...)
#      53         alert = driver.switch_to.alert
#      54 """
#      55 alert = Alert(self._driver)
# ---> 56 _ = alert.text
#      57 return alert
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/common/alert.py:66, in Alert.text(self)
#      61 @property
#      62 def text(self):
#      63     """
#      64     Gets the text of the Alert.
#      65     """
# ---> 66     return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=114.0.5735.248)
# Stacktrace:
# 0   chromedriver                        0x0000000104573f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010456c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001041b0be8 chromedriver + 281576
# 3   chromedriver                        0x00000001041cae40 chromedriver + 388672
# 4   chromedriver                        0x00000001041cab70 chromedriver + 387952
# 5   chromedriver                        0x00000001041dff1c chromedriver + 474908
# 6   chromedriver                        0x00000001041e0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010453559c chromedriver + 3970460
# 8   chromedriver                        0x00000001045396f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010453f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010453a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001045121c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000104556088 chromedriver + 4104328
# 13  chromedriver                        0x00000001045561e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000104565f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a6af9240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a6af4024 thread_start + 8

# %%
unishippers.alarm.fadeout(1200)

# %%
unishippers.cancel_lead()
unishippers.start_new_lead()
# Out:
# canceling lead
# starting new lead

# %%
driver.quit()

# %%
print(datetime.datetime.now().strftime("%-m/%-d/%Y %-I:%M:%S %p"))

# %%
parsed = usaddress.tag(
    "3452 East Foothill Boulevard, Pasadena, California, United States, 91107".replace(
        "United States, ", ""
    )
    .replace(", United States", "")
    .replace("United States", "")
)[0]
final = {
    "address": " ".join(
        (
            list(
                filter(
                    lambda x: x is not None,
                    [
                        parsed.get("BuildingName", None),
                        parsed.get("AddressNumber", None),
                        parsed.get("StreetNamePreDirectional", None),
                        parsed.get("StreetName", None),
                        parsed.get("StreetNamePostType", None),
                    ],
                )
            )
        )
    ),
    "city": parsed["PlaceName"],
    "state": parsed["StateName"],
    "zip_code": parsed["ZipCode"],
}
pprint.pp(final)
# Out:
# {'address': '3452 East Foothill Boulevard',
#  'city': 'Pasadena',
#  'state': 'California',
#  'zip_code': '91107'}

# %%
alert = driver.switch_to.alert
# Out:
# ---------------------------------------------------------------------------
# NoAlertPresentException                   Traceback (most recent call last)
# /Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/jackgeorge/Desktop/code/python/jp-macdonnel/scripts/request_green_light.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> alert = driver.switch_to.alert
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/switch_to.py:56, in SwitchTo.alert(self)
#      47 """
#      48 Switches focus to an alert on the page.
#      49
#    (...)
#      53         alert = driver.switch_to.alert
#      54 """
#      55 alert = Alert(self._driver)
# ---> 56 _ = alert.text
#      57 return alert
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/common/alert.py:66, in Alert.text(self)
#      61 @property
#      62 def text(self):
#      63     """
#      64     Gets the text of the Alert.
#      65     """
# ---> 66     return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File /opt/homebrew/lib/python3.9/site-packages/selenium/webdriver/remote/errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=114.0.5735.248)
# Stacktrace:
# 0   chromedriver                        0x0000000104573f48 chromedriver + 4226888
# 1   chromedriver                        0x000000010456c4f4 chromedriver + 4195572
# 2   chromedriver                        0x00000001041b0be8 chromedriver + 281576
# 3   chromedriver                        0x00000001041cae40 chromedriver + 388672
# 4   chromedriver                        0x00000001041cab70 chromedriver + 387952
# 5   chromedriver                        0x00000001041dff1c chromedriver + 474908
# 6   chromedriver                        0x00000001041e0ef4 chromedriver + 478964
# 7   chromedriver                        0x000000010453559c chromedriver + 3970460
# 8   chromedriver                        0x00000001045396f0 chromedriver + 3987184
# 9   chromedriver                        0x000000010453f5b4 chromedriver + 4011444
# 10  chromedriver                        0x000000010453a2fc chromedriver + 3990268
# 11  chromedriver                        0x00000001045121c0 chromedriver + 3826112
# 12  chromedriver                        0x0000000104556088 chromedriver + 4104328
# 13  chromedriver                        0x00000001045561e0 chromedriver + 4104672
# 14  chromedriver                        0x0000000104565f28 chromedriver + 4169512
# 15  libsystem_pthread.dylib             0x00000001a6af9240 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x00000001a6af4024 thread_start + 8

# %%
alert.text
# Out:
# "[1]Error invoking service 'SetNewLeadStatus', method 'Set_LeadStatus' at step 'Set Dates and Status'.(SBL-BPR-00162)\n[2]This operation is not available for read only field 'ABCD Account Status'.(SBL-DAT-00402)\n"

# %%
from selenium.webdriver.common.alert import Alert

try:
    unishippers.save_form()
except UnexpectedAlertPresentException as e:
    print("msg", e.msg)
    sleep(5)
    print("switching to alert")
    try:
        driver.switch_to.alert.accept()
    except Exception as e:
        print("msg", e.msg)
        try:
            Alert(driver).dismiss()
        except Exception as e:
            print("msg", e.msg)
            print("continuing")
            pass

driver.find_element(By.ID, "s_1_1_48_0_Ctrl").click()
# Out:
# saving form
# still saving
# msg unexpected alert open: {Alert text : [1]Error invoking service 'SetNewLeadStatus', method 'Set_LeadStatus' at step 'Set Dates and Status'.(SBL-BPR-00162)
# [2]This operation is not available for read only field 'ABCD Account Status'.(SBL-DAT-00402)
# }
#   (Session info: chrome=114.0.5735.248)
# switching to alert
# msg no such alert
#   (Session info: chrome=114.0.5735.248)
# msg no such alert
#   (Session info: chrome=114.0.5735.248)
# continuing

# %%
unishippers.check_protection_status()
# Out:
# checking protection status
# attempting check_protection_status for the 1 time
# checking protection status
# attempting check_protection_status for the 2 time
# checking protection status
# attempting check_protection_status for the 3 time
# checking protection status
# attempting check_protection_status for the 4 time
# checking protection status
# attempting check_protection_status for the 5 time
# checking protection status
# attempting check_protection_status for the 6 time
# checking protection status
# attempting check_protection_status for the 7 time
# checking protection status
# attempting check_protection_status for the 8 time
# checking protection status
# attempting check_protection_status for the 9 time
# checking protection status
# attempting check_protection_status for the 10 time
# checking protection status
# attempting check_protection_status for the 11 time
# checking protection status
# Unable to get protection status
